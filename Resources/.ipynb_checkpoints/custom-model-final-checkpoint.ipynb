# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import (confusion_matrix, classification_report,
                             precision_score, recall_score, f1_score,
                             ConfusionMatrixDisplay)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import (GlobalAveragePooling2D, Dense, Dropout,
                                     BatchNormalization, Conv2D, MaxPooling2D,
                                     Input, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback
from tensorflow.keras.regularizers import l2

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)

print("="*70)
print("🚀 SUPERVISED LEARNING FOR MANGO LEAF DISEASE")
print("="*70)

# ============================================================================
# CONFIGURATION
# ============================================================================
DATA_DIR = '/kaggle/input/mango-leaf-disease-dataset'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

# Training configuration
TRAIN_CONFIG = {
    'epochs': 100,  # More epochs for supervised learning
    'early_stopping_patience': 20,
    'lr_patience': 8,
    'initial_lr': 1e-3,
}

# ============================================================================
# LOAD DATA
# ============================================================================
print("\n=== Loading Dataset ===")
filepaths = []
labels = []
for label in sorted(os.listdir(DATA_DIR)):
    label_path = os.path.join(DATA_DIR, label)
    if os.path.isdir(label_path):
        for file in os.listdir(label_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(label_path, file))
                labels.append(label)

df = pd.DataFrame({'filename': filepaths, 'class': labels})
classes = sorted(df['class'].unique())
num_classes = len(classes)

print(f"Total samples: {len(df)}")
print(f"Classes: {classes}")

# Display class distribution
print("\nClass distribution:")
class_counts = df['class'].value_counts()
for cls, count in class_counts.items():
    print(f"  {cls}: {count} samples ({100*count/len(df):.1f}%)")

# ============================================================================
# SPLIT DATA
# ============================================================================
print("\n=== Splitting Data ===")
# First split: separate test set
train_val_df, test_df = train_test_split(
    df, test_size=0.15, stratify=df['class'], random_state=SEED
)

# Second split: separate training and validation
train_df, val_df = train_test_split(
    train_val_df, test_size=0.15, stratify=train_val_df['class'], random_state=SEED
)

print(f"Data split:")
print(f"  Training: {len(train_df)} ({100*len(train_df)/len(df):.1f}%)")
print(f"  Validation: {len(val_df)} ({100*len(val_df)/len(df):.1f}%)")
print(f"  Test: {len(test_df)} ({100*len(test_df)/len(df):.1f}%)")

# ============================================================================
# DATA GENERATORS WITH AGGRESSIVE AUGMENTATION
# ============================================================================
print("\n=== Creating Data Generators ===")

# Aggressive augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest',
    channel_shift_range=20.0,
)

# Only rescaling for validation and test
val_test_datagen = ImageDataGenerator(rescale=1./255)

class_names = sorted(df['class'].unique())

# ============================================================================
# BUILD REGULARIZED MODEL
# ============================================================================
def build_model(input_shape=(224, 224, 3), num_classes=8):
    """
    Model with heavy regularization to prevent overfitting
    """
    inputs = Input(shape=input_shape)
    
    # Block 1
    x = Conv2D(32, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.2)(x)
    
    # Block 2
    x = Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)
    
    # Block 3
    x = Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    
    # Block 4
    x = Conv2D(256, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.5)(x)
    
    # Head with heavy dropout
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.6)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    return model

print("\n=== Building Model ===")
model = build_model(input_shape=IMG_SIZE + (3,), num_classes=num_classes)
print(f"Model parameters: {model.count_params():,}")

# ============================================================================
# CUSTOM CALLBACK
# ============================================================================
class TrainingMonitor(Callback):
    def __init__(self):
        super().__init__()
        self.best_val_acc = 0
        
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_acc = logs.get('val_accuracy', 0)
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            print(f"\n🎯 New best val_acc: {val_acc:.4f}")

# ============================================================================
# CREATE DATA GENERATORS
# ============================================================================
print("\n=== Preparing Data Generators ===")

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED,
    classes=class_names
)

val_gen = val_test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    classes=class_names
)

test_gen = val_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    classes=class_names
)

# ============================================================================
# CALCULATE CLASS WEIGHTS (for imbalanced datasets)
# ============================================================================
print("\n=== Calculating Class Weights ===")
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_df['class']),
    y=train_df['class']
)
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

print("Class weights:")
for i, (cls, weight) in enumerate(zip(class_names, class_weights)):
    print(f"  {cls}: {weight:.3f}")

# ============================================================================
# COMPILE AND TRAIN MODEL
# ============================================================================
print("\n" + "="*70)
print("TRAINING MODEL")
print("="*70)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=TRAIN_CONFIG['initial_lr']),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=TRAIN_CONFIG['early_stopping_patience'],
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=TRAIN_CONFIG['lr_patience'],
    min_lr=1e-7,
    mode='max',
    verbose=1
)

monitor = TrainingMonitor()

# Train model
print("\nTraining model with all labeled data...")
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=TRAIN_CONFIG['epochs'],
    class_weight=class_weights_dict,  # Handle class imbalance
    callbacks=[early_stop, reduce_lr, monitor],
    verbose=2
)

# ============================================================================
# EVALUATE MODEL
# ============================================================================
print("\n" + "="*70)
print("MODEL EVALUATION")
print("="*70)

# Evaluate on validation set
val_loss, val_acc = model.evaluate(val_gen, verbose=1)
print(f"\n📊 Validation Results:")
print(f"   Accuracy: {val_acc:.4f}")
print(f"   Loss: {val_loss:.4f}")

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n🎯 Test Results:")
print(f"   Accuracy: {test_acc:.4f}")
print(f"   Loss: {test_loss:.4f}")

# ============================================================================
# DETAILED METRICS
# ============================================================================
print("\n" + "="*70)
print("DETAILED METRICS")
print("="*70)

# Get predictions
y_pred_probs = model.predict(test_gen, verbose=0)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_true_labels = test_gen.classes

# Classification report
print("\nClassification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=classes))

# Calculate metrics
test_precision = precision_score(y_true_labels, y_pred_labels, average='macro')
test_recall = recall_score(y_true_labels, y_pred_labels, average='macro')
test_f1 = f1_score(y_true_labels, y_pred_labels, average='macro')

print(f"\n📊 Summary Metrics:")
print(f"   Precision: {test_precision:.4f}")
print(f"   Recall: {test_recall:.4f}")
print(f"   F1-Score: {test_f1:.4f}")

# ============================================================================
# VISUALIZATION
# ============================================================================
print("\n=== Generating Visualizations ===")

# Training curves
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Training', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validation', linewidth=2)
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Training', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validation', linewidth=2)
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# Confusion Matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(12, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', values_format='d', xticks_rotation=45)
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Per-class accuracy
class_accuracies = {}
for i, cls in enumerate(classes):
    mask = (y_true_labels == i)
    if mask.sum() > 0:
        class_acc = (y_pred_labels[mask] == y_true_labels[mask]).mean()
        class_accuracies[cls] = class_acc

print("\nPer-class Accuracy:")
for cls, acc in sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True):
    print(f"  {cls}: {acc:.4f}")

print("\n✅ Supervised learning completed!")
# Out:
# 2025-10-24 21:44:33.426255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761342273.649711      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761342273.727832      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ======================================================================
# 🚀 SUPERVISED LEARNING FOR MANGO LEAF DISEASE
# ======================================================================
#
# === Loading Dataset ===
# Total samples: 4000
# Classes: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']
#
# Class distribution:
#   Anthracnose: 500 samples (12.5%)
#   Bacterial Canker: 500 samples (12.5%)
#   Cutting Weevil: 500 samples (12.5%)
#   Die Back: 500 samples (12.5%)
#   Gall Midge: 500 samples (12.5%)
#   Healthy: 500 samples (12.5%)
#   Powdery Mildew: 500 samples (12.5%)
#   Sooty Mould: 500 samples (12.5%)
#
# === Splitting Data ===
# Data split:
#   Training: 2890 (72.2%)
#   Validation: 510 (12.8%)
#   Test: 600 (15.0%)
#
# === Creating Data Generators ===
#
# === Building Model ===
# I0000 00:00:1761342287.375047      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761342287.375748      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model parameters: 490,056
#
# === Preparing Data Generators ===
# Found 2890 validated image filenames belonging to 8 classes.
# Found 510 validated image filenames belonging to 8 classes.
# Found 600 validated image filenames belonging to 8 classes.
#
# === Calculating Class Weights ===
# Class weights:
#   Anthracnose: 1.001
#   Bacterial Canker: 0.998
#   Cutting Weevil: 1.001
#   Die Back: 1.001
#   Gall Midge: 1.001
#   Healthy: 0.998
#   Powdery Mildew: 1.001
#   Sooty Mould: 1.001
#
# ======================================================================
# TRAINING MODEL
# ======================================================================
#
# Training model with all labeled data...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761342307.905773      97 service.cc:148] XLA service 0x7b4474015b80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761342307.907034      97 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761342307.907062      97 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761342308.577643      97 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1761342318.392294      97 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 🎯 New best val_acc: 0.1765
# 91/91 - 82s - 906ms/step - accuracy: 0.2948 - loss: 1.9364 - val_accuracy: 0.1765 - val_loss: 2.5874 - learning_rate: 0.0010
# Epoch 2/100
#
# 🎯 New best val_acc: 0.2196
# 91/91 - 40s - 438ms/step - accuracy: 0.4965 - loss: 1.4198 - val_accuracy: 0.2196 - val_loss: 3.6061 - learning_rate: 0.0010
# Epoch 3/100
# 91/91 - 39s - 428ms/step - accuracy: 0.6260 - loss: 1.1078 - val_accuracy: 0.2157 - val_loss: 3.1917 - learning_rate: 0.0010
# Epoch 4/100
# 91/91 - 39s - 427ms/step - accuracy: 0.6630 - loss: 1.0064 - val_accuracy: 0.1902 - val_loss: 3.9001 - learning_rate: 0.0010
# Epoch 5/100
#
# 🎯 New best val_acc: 0.4118
# 91/91 - 39s - 431ms/step - accuracy: 0.6785 - loss: 0.9558 - val_accuracy: 0.4118 - val_loss: 1.8052 - learning_rate: 0.0010
# Epoch 6/100
#
# 🎯 New best val_acc: 0.5020
# 91/91 - 39s - 428ms/step - accuracy: 0.7273 - loss: 0.8162 - val_accuracy: 0.5020 - val_loss: 1.6818 - learning_rate: 0.0010
# Epoch 7/100
#
# 🎯 New best val_acc: 0.6412
# 91/91 - 39s - 432ms/step - accuracy: 0.7453 - loss: 0.7774 - val_accuracy: 0.6412 - val_loss: 0.9889 - learning_rate: 0.0010
# Epoch 8/100
# 91/91 - 39s - 431ms/step - accuracy: 0.7460 - loss: 0.7559 - val_accuracy: 0.6353 - val_loss: 1.2547 - learning_rate: 0.0010
# Epoch 9/100
# 91/91 - 39s - 430ms/step - accuracy: 0.7623 - loss: 0.7280 - val_accuracy: 0.4078 - val_loss: 2.1142 - learning_rate: 0.0010
# Epoch 10/100
#
# 🎯 New best val_acc: 0.6529
# 91/91 - 39s - 431ms/step - accuracy: 0.7713 - loss: 0.7268 - val_accuracy: 0.6529 - val_loss: 1.0899 - learning_rate: 0.0010
# Epoch 11/100
# 91/91 - 39s - 424ms/step - accuracy: 0.7817 - loss: 0.6864 - val_accuracy: 0.5725 - val_loss: 1.2164 - learning_rate: 0.0010
# Epoch 12/100
#
# 🎯 New best val_acc: 0.6667
# 91/91 - 39s - 432ms/step - accuracy: 0.7945 - loss: 0.6463 - val_accuracy: 0.6667 - val_loss: 0.9713 - learning_rate: 0.0010
# Epoch 13/100
# 91/91 - 39s - 426ms/step - accuracy: 0.8111 - loss: 0.5922 - val_accuracy: 0.3824 - val_loss: 5.0600 - learning_rate: 0.0010
# Epoch 14/100
# 91/91 - 39s - 432ms/step - accuracy: 0.8201 - loss: 0.5896 - val_accuracy: 0.5333 - val_loss: 3.4170 - learning_rate: 0.0010
# Epoch 15/100
#
# 🎯 New best val_acc: 0.8196
# 91/91 - 39s - 429ms/step - accuracy: 0.8201 - loss: 0.5804 - val_accuracy: 0.8196 - val_loss: 0.5299 - learning_rate: 0.0010
# Epoch 16/100
# 91/91 - 39s - 433ms/step - accuracy: 0.8356 - loss: 0.5399 - val_accuracy: 0.5118 - val_loss: 2.3973 - learning_rate: 0.0010
# Epoch 17/100
# 91/91 - 40s - 436ms/step - accuracy: 0.8433 - loss: 0.5257 - val_accuracy: 0.5353 - val_loss: 1.8866 - learning_rate: 0.0010
# Epoch 18/100
# 91/91 - 39s - 429ms/step - accuracy: 0.8464 - loss: 0.5160 - val_accuracy: 0.5333 - val_loss: 1.7347 - learning_rate: 0.0010
# Epoch 19/100
#
# 🎯 New best val_acc: 0.8431
# 91/91 - 40s - 436ms/step - accuracy: 0.8453 - loss: 0.5166 - val_accuracy: 0.8431 - val_loss: 0.5547 - learning_rate: 0.0010
# Epoch 20/100
# 91/91 - 39s - 432ms/step - accuracy: 0.8436 - loss: 0.5219 - val_accuracy: 0.7980 - val_loss: 0.7187 - learning_rate: 0.0010
# Epoch 21/100
# 91/91 - 39s - 431ms/step - accuracy: 0.8495 - loss: 0.5198 - val_accuracy: 0.7314 - val_loss: 0.7463 - learning_rate: 0.0010
# Epoch 22/100
# 91/91 - 39s - 424ms/step - accuracy: 0.8533 - loss: 0.5161 - val_accuracy: 0.7333 - val_loss: 0.7285 - learning_rate: 0.0010
# Epoch 23/100
# 91/91 - 39s - 431ms/step - accuracy: 0.8651 - loss: 0.4632 - val_accuracy: 0.3784 - val_loss: 5.1384 - learning_rate: 0.0010
# Epoch 24/100
# 91/91 - 39s - 430ms/step - accuracy: 0.8581 - loss: 0.4908 - val_accuracy: 0.4569 - val_loss: 2.7067 - learning_rate: 0.0010
# Epoch 25/100
#
# 🎯 New best val_acc: 0.8451
# 91/91 - 39s - 430ms/step - accuracy: 0.8678 - loss: 0.4925 - val_accuracy: 0.8451 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 26/100
# 91/91 - 39s - 425ms/step - accuracy: 0.8803 - loss: 0.4438 - val_accuracy: 0.7235 - val_loss: 0.8468 - learning_rate: 0.0010
# Epoch 27/100
#
# 🎯 New best val_acc: 0.8706
# 91/91 - 40s - 435ms/step - accuracy: 0.8813 - loss: 0.4282 - val_accuracy: 0.8706 - val_loss: 0.4421 - learning_rate: 0.0010
# Epoch 28/100
# 91/91 - 39s - 425ms/step - accuracy: 0.8875 - loss: 0.4216 - val_accuracy: 0.5725 - val_loss: 1.2391 - learning_rate: 0.0010
# Epoch 29/100
# 91/91 - 39s - 424ms/step - accuracy: 0.8830 - loss: 0.4127 - val_accuracy: 0.6804 - val_loss: 1.1034 - learning_rate: 0.0010
# Epoch 30/100
# 91/91 - 39s - 426ms/step - accuracy: 0.8682 - loss: 0.4805 - val_accuracy: 0.6843 - val_loss: 1.2028 - learning_rate: 0.0010
# Epoch 31/100
# 91/91 - 39s - 431ms/step - accuracy: 0.8990 - loss: 0.4116 - val_accuracy: 0.6431 - val_loss: 2.0467 - learning_rate: 0.0010
# Epoch 32/100
# 91/91 - 39s - 429ms/step - accuracy: 0.8813 - loss: 0.4379 - val_accuracy: 0.8275 - val_loss: 0.5739 - learning_rate: 0.0010
# Epoch 33/100
#
# 🎯 New best val_acc: 0.8843
# 91/91 - 40s - 437ms/step - accuracy: 0.9000 - loss: 0.3990 - val_accuracy: 0.8843 - val_loss: 0.3798 - learning_rate: 0.0010
# Epoch 34/100
# 91/91 - 39s - 425ms/step - accuracy: 0.8952 - loss: 0.4032 - val_accuracy: 0.5569 - val_loss: 2.4193 - learning_rate: 0.0010
# Epoch 35/100
# 91/91 - 39s - 425ms/step - accuracy: 0.9007 - loss: 0.3913 - val_accuracy: 0.7078 - val_loss: 0.9517 - learning_rate: 0.0010
# Epoch 36/100
# 91/91 - 39s - 426ms/step - accuracy: 0.9080 - loss: 0.3756 - val_accuracy: 0.6353 - val_loss: 1.5447 - learning_rate: 0.0010
# Epoch 37/100
# 91/91 - 39s - 425ms/step - accuracy: 0.9021 - loss: 0.4064 - val_accuracy: 0.7314 - val_loss: 0.8568 - learning_rate: 0.0010
# Epoch 38/100
#
# 🎯 New best val_acc: 0.9137
# 91/91 - 39s - 427ms/step - accuracy: 0.9111 - loss: 0.3590 - val_accuracy: 0.9137 - val_loss: 0.3625 - learning_rate: 0.0010
# Epoch 39/100
# 91/91 - 39s - 427ms/step - accuracy: 0.9118 - loss: 0.3680 - val_accuracy: 0.9098 - val_loss: 0.4297 - learning_rate: 0.0010
# Epoch 40/100
# 91/91 - 38s - 422ms/step - accuracy: 0.9242 - loss: 0.3300 - val_accuracy: 0.6765 - val_loss: 1.2414 - learning_rate: 0.0010
# Epoch 41/100
#
# 🎯 New best val_acc: 0.9275
# 91/91 - 38s - 423ms/step - accuracy: 0.9187 - loss: 0.3387 - val_accuracy: 0.9275 - val_loss: 0.3934 - learning_rate: 0.0010
# Epoch 42/100
# 91/91 - 39s - 427ms/step - accuracy: 0.9163 - loss: 0.3303 - val_accuracy: 0.8765 - val_loss: 0.4664 - learning_rate: 0.0010
# Epoch 43/100
# 91/91 - 38s - 422ms/step - accuracy: 0.8997 - loss: 0.4078 - val_accuracy: 0.7667 - val_loss: 1.0158 - learning_rate: 0.0010
# Epoch 44/100
# 91/91 - 39s - 425ms/step - accuracy: 0.9142 - loss: 0.3596 - val_accuracy: 0.8608 - val_loss: 0.4848 - learning_rate: 0.0010
# Epoch 45/100
# 91/91 - 39s - 428ms/step - accuracy: 0.9159 - loss: 0.3310 - val_accuracy: 0.8510 - val_loss: 0.6838 - learning_rate: 0.0010
# Epoch 46/100
# 91/91 - 39s - 431ms/step - accuracy: 0.9318 - loss: 0.3176 - val_accuracy: 0.8608 - val_loss: 0.4810 - learning_rate: 0.0010
# Epoch 47/100
#
# 🎯 New best val_acc: 0.9686
# 91/91 - 39s - 428ms/step - accuracy: 0.9315 - loss: 0.3073 - val_accuracy: 0.9686 - val_loss: 0.2217 - learning_rate: 0.0010
# Epoch 48/100
# 91/91 - 39s - 426ms/step - accuracy: 0.9363 - loss: 0.2884 - val_accuracy: 0.8902 - val_loss: 0.4206 - learning_rate: 0.0010
# Epoch 49/100
# 91/91 - 38s - 422ms/step - accuracy: 0.9183 - loss: 0.3544 - val_accuracy: 0.7471 - val_loss: 0.9740 - learning_rate: 0.0010
# Epoch 50/100
# 91/91 - 38s - 420ms/step - accuracy: 0.9356 - loss: 0.3060 - val_accuracy: 0.7706 - val_loss: 0.8613 - learning_rate: 0.0010
# Epoch 51/100
# 91/91 - 38s - 421ms/step - accuracy: 0.9388 - loss: 0.2899 - val_accuracy: 0.9196 - val_loss: 0.3569 - learning_rate: 0.0010
# Epoch 52/100
# 91/91 - 39s - 423ms/step - accuracy: 0.9260 - loss: 0.3241 - val_accuracy: 0.6863 - val_loss: 1.3843 - learning_rate: 0.0010
# Epoch 53/100
# 91/91 - 38s - 421ms/step - accuracy: 0.9360 - loss: 0.3012 - val_accuracy: 0.9431 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 54/100
# 91/91 - 38s - 422ms/step - accuracy: 0.9412 - loss: 0.2915 - val_accuracy: 0.9392 - val_loss: 0.2879 - learning_rate: 0.0010
# Epoch 55/100
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 91/91 - 38s - 419ms/step - accuracy: 0.9360 - loss: 0.3044 - val_accuracy: 0.9314 - val_loss: 0.3155 - learning_rate: 0.0010
# Epoch 56/100
# 91/91 - 39s - 425ms/step - accuracy: 0.9526 - loss: 0.2486 - val_accuracy: 0.9608 - val_loss: 0.2752 - learning_rate: 5.0000e-04
# Epoch 57/100
# 91/91 - 38s - 418ms/step - accuracy: 0.9644 - loss: 0.2217 - val_accuracy: 0.9647 - val_loss: 0.2413 - learning_rate: 5.0000e-04
# Epoch 58/100
# 91/91 - 38s - 419ms/step - accuracy: 0.9554 - loss: 0.2480 - val_accuracy: 0.9314 - val_loss: 0.2824 - learning_rate: 5.0000e-04
# Epoch 59/100
# 91/91 - 39s - 423ms/step - accuracy: 0.9678 - loss: 0.2013 - val_accuracy: 0.9490 - val_loss: 0.2426 - learning_rate: 5.0000e-04
# Epoch 60/100
# 91/91 - 38s - 418ms/step - accuracy: 0.9619 - loss: 0.2106 - val_accuracy: 0.9431 - val_loss: 0.2869 - learning_rate: 5.0000e-04
# Epoch 61/100
# 91/91 - 38s - 420ms/step - accuracy: 0.9730 - loss: 0.1885 - val_accuracy: 0.9608 - val_loss: 0.2410 - learning_rate: 5.0000e-04
# Epoch 62/100
# 91/91 - 39s - 424ms/step - accuracy: 0.9637 - loss: 0.2111 - val_accuracy: 0.9667 - val_loss: 0.2094 - learning_rate: 5.0000e-04
# Epoch 63/100
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 91/91 - 38s - 421ms/step - accuracy: 0.9671 - loss: 0.2056 - val_accuracy: 0.9333 - val_loss: 0.2971 - learning_rate: 5.0000e-04
# Epoch 64/100
# 91/91 - 39s - 424ms/step - accuracy: 0.9702 - loss: 0.1932 - val_accuracy: 0.9627 - val_loss: 0.2080 - learning_rate: 2.5000e-04
# Epoch 65/100
# 91/91 - 39s - 432ms/step - accuracy: 0.9716 - loss: 0.1830 - val_accuracy: 0.9510 - val_loss: 0.2069 - learning_rate: 2.5000e-04
# Epoch 66/100
# 91/91 - 39s - 431ms/step - accuracy: 0.9727 - loss: 0.1767 - val_accuracy: 0.9608 - val_loss: 0.2374 - learning_rate: 2.5000e-04
# Epoch 67/100
# 91/91 - 40s - 439ms/step - accuracy: 0.9810 - loss: 0.1658 - val_accuracy: 0.9588 - val_loss: 0.2277 - learning_rate: 2.5000e-04
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 47.
#
# ======================================================================
# MODEL EVALUATION
# ======================================================================
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9744 - loss: 0.2121
#
# 📊 Validation Results:
#    Accuracy: 0.9686
#    Loss: 0.2217
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 409ms/step - accuracy: 0.9686 - loss: 0.1674
#
# 🎯 Test Results:
#    Accuracy: 0.9650
#    Loss: 0.1759
#
# ======================================================================
# DETAILED METRICS
# ======================================================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.97      0.97      0.97        75
# Bacterial Canker       0.97      1.00      0.99        75
#   Cutting Weevil       1.00      0.99      0.99        75
#         Die Back       0.99      1.00      0.99        75
#       Gall Midge       0.97      0.92      0.95        75
#          Healthy       0.97      0.99      0.98        75
#   Powdery Mildew       0.88      0.97      0.92        75
#      Sooty Mould       0.97      0.88      0.92        75
#
#         accuracy                           0.96       600
#        macro avg       0.97      0.97      0.96       600
#     weighted avg       0.97      0.96      0.96       600
#
#
# 📊 Summary Metrics:
#    Precision: 0.9662
#    Recall: 0.9650
#    F1-Score: 0.9649
#
# === Generating Visualizations ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37/421343471.py in <cell line: 0>()
#     369 for i, cls in enumerate(classes):
#     370     mask = (y_true_labels == i)
# --> 371     if mask.sum() > 0:
#     372         class_acc = (y_pred_labels[mask] == y_true_labels[mask]).mean()
#     373         class_accuracies[cls] = class_acc
#
# AttributeError: 'bool' object has no attribute 'sum'
