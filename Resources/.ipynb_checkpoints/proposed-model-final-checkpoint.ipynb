# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import (confusion_matrix, classification_report,
                             precision_score, recall_score, f1_score,
                             ConfusionMatrixDisplay)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import (GlobalAveragePooling2D, Dense, Dropout,
                                     BatchNormalization, Conv2D, MaxPooling2D,
                                     Input, Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback
from tensorflow.keras.regularizers import l2

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)

print("="*70)
print("🚀 SUPERVISED LEARNING FOR MANGO LEAF DISEASE")
print("="*70)

# ============================================================================
# CONFIGURATION
# ============================================================================
DATA_DIR = '/kaggle/input/mango-leaf-disease-dataset'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42

# Training configuration
TRAIN_CONFIG = {
    'epochs': 100,  # More epochs for supervised learning
    'early_stopping_patience': 20,
    'lr_patience': 8,
    'initial_lr': 1e-3,
}

# ============================================================================
# LOAD DATA
# ============================================================================
print("\n=== Loading Dataset ===")
filepaths = []
labels = []
for label in sorted(os.listdir(DATA_DIR)):
    label_path = os.path.join(DATA_DIR, label)
    if os.path.isdir(label_path):
        for file in os.listdir(label_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(label_path, file))
                labels.append(label)

df = pd.DataFrame({'filename': filepaths, 'class': labels})
classes = sorted(df['class'].unique())
num_classes = len(classes)

print(f"Total samples: {len(df)}")
print(f"Classes: {classes}")

# Display class distribution
print("\nClass distribution:")
class_counts = df['class'].value_counts()
for cls, count in class_counts.items():
    print(f"  {cls}: {count} samples ({100*count/len(df):.1f}%)")

# ============================================================================
# SPLIT DATA
# ============================================================================
print("\n=== Splitting Data ===")
# First split: separate test set
train_val_df, test_df = train_test_split(
    df, test_size=0.1, stratify=df['class'], random_state=SEED
)

# Second split: separate training and validation
train_df, val_df = train_test_split(
    train_val_df, test_size=0.1, stratify=train_val_df['class'], random_state=SEED
)

print(f"Data split:")
print(f"  Training: {len(train_df)} ({100*len(train_df)/len(df):.1f}%)")
print(f"  Validation: {len(val_df)} ({100*len(val_df)/len(df):.1f}%)")
print(f"  Test: {len(test_df)} ({100*len(test_df)/len(df):.1f}%)")

# ============================================================================
# DATA GENERATORS WITH AGGRESSIVE AUGMENTATION
# ============================================================================
print("\n=== Creating Data Generators ===")

# Aggressive augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest',
    channel_shift_range=20.0,
)

# Only rescaling for validation and test
val_test_datagen = ImageDataGenerator(rescale=1./255)

class_names = sorted(df['class'].unique())

# ============================================================================
# BUILD REGULARIZED MODEL
# ============================================================================
def build_model(input_shape=(224, 224, 3), num_classes=8):
    """
    Model with heavy regularization to prevent overfitting
    """
    inputs = Input(shape=input_shape)
    
    # Block 1
    x = Conv2D(32, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.2)(x)
    
    # Block 2
    x = Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)
    
    # Block 3
    x = Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    
    # Block 4
    x = Conv2D(256, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.5)(x)
    
    # Head with heavy dropout
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.6)(x)
    x = Dense(128, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    return model

print("\n=== Building Model ===")
model = build_model(input_shape=IMG_SIZE + (3,), num_classes=num_classes)
print(f"Model parameters: {model.count_params():,}")

# ============================================================================
# CUSTOM CALLBACK
# ============================================================================
class TrainingMonitor(Callback):
    def __init__(self):
        super().__init__()
        self.best_val_acc = 0
        
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_acc = logs.get('val_accuracy', 0)
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            print(f"\n🎯 New best val_acc: {val_acc:.4f}")

# ============================================================================
# CREATE DATA GENERATORS
# ============================================================================
print("\n=== Preparing Data Generators ===")

train_gen = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED,
    classes=class_names
)

val_gen = val_test_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    classes=class_names
)

test_gen = val_test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    classes=class_names
)

# ============================================================================
# CALCULATE CLASS WEIGHTS (for imbalanced datasets)
# ============================================================================
print("\n=== Calculating Class Weights ===")
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_df['class']),
    y=train_df['class']
)
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

print("Class weights:")
for i, (cls, weight) in enumerate(zip(class_names, class_weights)):
    print(f"  {cls}: {weight:.3f}")

# ============================================================================
# COMPILE AND TRAIN MODEL
# ============================================================================
print("\n" + "="*70)
print("TRAINING MODEL")
print("="*70)

# Compile model
model.compile(
    optimizer=Adam(learning_rate=TRAIN_CONFIG['initial_lr']),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=TRAIN_CONFIG['early_stopping_patience'],
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=TRAIN_CONFIG['lr_patience'],
    min_lr=1e-7,
    mode='max',
    verbose=1
)

monitor = TrainingMonitor()

# Train model
print("\nTraining model with all labeled data...")
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=TRAIN_CONFIG['epochs'],
    class_weight=class_weights_dict,  # Handle class imbalance
    callbacks=[early_stop, reduce_lr, monitor],
    verbose=2
)

# ============================================================================
# EVALUATE MODEL
# ============================================================================
print("\n" + "="*70)
print("MODEL EVALUATION")
print("="*70)

# Evaluate on validation set
val_loss, val_acc = model.evaluate(val_gen, verbose=1)
print(f"\n📊 Validation Results:")
print(f"   Accuracy: {val_acc:.4f}")
print(f"   Loss: {val_loss:.4f}")

# Evaluate on test set
test_loss, test_acc = model.evaluate(test_gen, verbose=1)
print(f"\n🎯 Test Results:")
print(f"   Accuracy: {test_acc:.4f}")
print(f"   Loss: {test_loss:.4f}")

# ============================================================================
# DETAILED METRICS
# ============================================================================
print("\n" + "="*70)
print("DETAILED METRICS")
print("="*70)

# Get predictions
y_pred_probs = model.predict(test_gen, verbose=0)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
y_true_labels = test_gen.classes

# Classification report
print("\nClassification Report:")
print(classification_report(y_true_labels, y_pred_labels, target_names=classes))

# Calculate metrics
test_precision = precision_score(y_true_labels, y_pred_labels, average='macro')
test_recall = recall_score(y_true_labels, y_pred_labels, average='macro')
test_f1 = f1_score(y_true_labels, y_pred_labels, average='macro')

print(f"\n📊 Summary Metrics:")
print(f"   Precision: {test_precision:.4f}")
print(f"   Recall: {test_recall:.4f}")
print(f"   F1-Score: {test_f1:.4f}")

# ============================================================================
# VISUALIZATION
# ============================================================================
print("\n=== Generating Visualizations ===")

# Training curves
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy plot
axes[0].plot(history.history['accuracy'], label='Training', linewidth=2)
axes[0].plot(history.history['val_accuracy'], label='Validation', linewidth=2)
axes[0].set_title('Model Accuracy', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='Training', linewidth=2)
axes[1].plot(history.history['val_loss'], label='Validation', linewidth=2)
axes[1].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# Confusion Matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(12, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='Blues', values_format='d', xticks_rotation=45)
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

# Per-class accuracy
class_accuracies = {}
for i, cls in enumerate(classes):
    mask = (y_true_labels == i)
    if mask.sum() > 0:
        class_acc = (y_pred_labels[mask] == y_true_labels[mask]).mean()
        class_accuracies[cls] = class_acc

print("\nPer-class Accuracy:")
for cls, acc in sorted(class_accuracies.items(), key=lambda x: x[1], reverse=True):
    print(f"  {cls}: {acc:.4f}")

print("\n✅ Supervised learning completed!")
# Out:
# 2025-10-25 06:37:50.900024: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761374271.329357      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761374271.437487      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ======================================================================
# 🚀 SUPERVISED LEARNING FOR MANGO LEAF DISEASE
# ======================================================================
#
# === Loading Dataset ===
# Total samples: 4000
# Classes: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']
#
# Class distribution:
#   Anthracnose: 500 samples (12.5%)
#   Bacterial Canker: 500 samples (12.5%)
#   Cutting Weevil: 500 samples (12.5%)
#   Die Back: 500 samples (12.5%)
#   Gall Midge: 500 samples (12.5%)
#   Healthy: 500 samples (12.5%)
#   Powdery Mildew: 500 samples (12.5%)
#   Sooty Mould: 500 samples (12.5%)
#
# === Splitting Data ===
# Data split:
#   Training: 3240 (81.0%)
#   Validation: 360 (9.0%)
#   Test: 400 (10.0%)
#
# === Creating Data Generators ===
#
# === Building Model ===
# I0000 00:00:1761374289.663730      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761374289.664550      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model parameters: 490,056
#
# === Preparing Data Generators ===
# Found 3240 validated image filenames belonging to 8 classes.
# Found 360 validated image filenames belonging to 8 classes.
# Found 400 validated image filenames belonging to 8 classes.
#
# === Calculating Class Weights ===
# Class weights:
#   Anthracnose: 1.000
#   Bacterial Canker: 1.000
#   Cutting Weevil: 1.000
#   Die Back: 1.000
#   Gall Midge: 1.000
#   Healthy: 1.000
#   Powdery Mildew: 1.000
#   Sooty Mould: 1.000
#
# ======================================================================
# TRAINING MODEL
# ======================================================================
#
# Training model with all labeled data...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761374313.241710      99 service.cc:148] XLA service 0x7f2360118ca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761374313.243880      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761374313.243902      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761374314.049531      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1761374324.471193      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 🎯 New best val_acc: 0.1167
# 102/102 - 97s - 947ms/step - accuracy: 0.3201 - loss: 1.8716 - val_accuracy: 0.1167 - val_loss: 2.6293 - learning_rate: 0.0010
# Epoch 2/100
#
# 🎯 New best val_acc: 0.2194
# 102/102 - 47s - 463ms/step - accuracy: 0.5410 - loss: 1.3103 - val_accuracy: 0.2194 - val_loss: 3.9558 - learning_rate: 0.0010
# Epoch 3/100
# 102/102 - 48s - 466ms/step - accuracy: 0.6463 - loss: 1.0526 - val_accuracy: 0.1472 - val_loss: 3.6221 - learning_rate: 0.0010
# Epoch 4/100
#
# 🎯 New best val_acc: 0.3028
# 102/102 - 48s - 469ms/step - accuracy: 0.6611 - loss: 0.9943 - val_accuracy: 0.3028 - val_loss: 2.0144 - learning_rate: 0.0010
# Epoch 5/100
#
# 🎯 New best val_acc: 0.7444
# 102/102 - 47s - 462ms/step - accuracy: 0.7123 - loss: 0.8468 - val_accuracy: 0.7444 - val_loss: 0.8536 - learning_rate: 0.0010
# Epoch 6/100
# 102/102 - 48s - 469ms/step - accuracy: 0.7343 - loss: 0.7860 - val_accuracy: 0.5139 - val_loss: 1.3442 - learning_rate: 0.0010
# Epoch 7/100
# 102/102 - 48s - 470ms/step - accuracy: 0.7528 - loss: 0.7695 - val_accuracy: 0.4389 - val_loss: 2.0383 - learning_rate: 0.0010
# Epoch 8/100
# 102/102 - 48s - 467ms/step - accuracy: 0.7704 - loss: 0.7114 - val_accuracy: 0.4611 - val_loss: 2.4207 - learning_rate: 0.0010
# Epoch 9/100
# 102/102 - 47s - 461ms/step - accuracy: 0.7753 - loss: 0.7197 - val_accuracy: 0.4472 - val_loss: 2.3762 - learning_rate: 0.0010
# Epoch 10/100
# 102/102 - 48s - 473ms/step - accuracy: 0.7920 - loss: 0.6600 - val_accuracy: 0.5667 - val_loss: 1.8345 - learning_rate: 0.0010
# Epoch 11/100
# 102/102 - 48s - 475ms/step - accuracy: 0.8077 - loss: 0.6296 - val_accuracy: 0.7139 - val_loss: 0.7870 - learning_rate: 0.0010
# Epoch 12/100
# 102/102 - 50s - 490ms/step - accuracy: 0.8142 - loss: 0.6020 - val_accuracy: 0.5500 - val_loss: 2.5710 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 102/102 - 50s - 491ms/step - accuracy: 0.8164 - loss: 0.5960 - val_accuracy: 0.4056 - val_loss: 2.9485 - learning_rate: 0.0010
# Epoch 14/100
# 102/102 - 51s - 497ms/step - accuracy: 0.8463 - loss: 0.5213 - val_accuracy: 0.6417 - val_loss: 1.7297 - learning_rate: 5.0000e-04
# Epoch 15/100
#
# 🎯 New best val_acc: 0.8889
# 102/102 - 50s - 493ms/step - accuracy: 0.8568 - loss: 0.4997 - val_accuracy: 0.8889 - val_loss: 0.3922 - learning_rate: 5.0000e-04
# Epoch 16/100
# 102/102 - 49s - 477ms/step - accuracy: 0.8494 - loss: 0.5147 - val_accuracy: 0.8833 - val_loss: 0.3893 - learning_rate: 5.0000e-04
# Epoch 17/100
# 102/102 - 48s - 466ms/step - accuracy: 0.8756 - loss: 0.4438 - val_accuracy: 0.8500 - val_loss: 0.4824 - learning_rate: 5.0000e-04
# Epoch 18/100
# 102/102 - 48s - 472ms/step - accuracy: 0.8790 - loss: 0.4351 - val_accuracy: 0.6389 - val_loss: 1.5996 - learning_rate: 5.0000e-04
# Epoch 19/100
# 102/102 - 47s - 465ms/step - accuracy: 0.8765 - loss: 0.4477 - val_accuracy: 0.8750 - val_loss: 0.4766 - learning_rate: 5.0000e-04
# Epoch 20/100
#
# 🎯 New best val_acc: 0.9028
# 102/102 - 48s - 473ms/step - accuracy: 0.8846 - loss: 0.4230 - val_accuracy: 0.9028 - val_loss: 0.3878 - learning_rate: 5.0000e-04
# Epoch 21/100
# 102/102 - 48s - 472ms/step - accuracy: 0.8864 - loss: 0.4219 - val_accuracy: 0.6861 - val_loss: 1.1217 - learning_rate: 5.0000e-04
# Epoch 22/100
# 102/102 - 46s - 452ms/step - accuracy: 0.8812 - loss: 0.4194 - val_accuracy: 0.8500 - val_loss: 0.4405 - learning_rate: 5.0000e-04
# Epoch 23/100
# 102/102 - 46s - 453ms/step - accuracy: 0.8877 - loss: 0.4106 - val_accuracy: 0.6472 - val_loss: 1.2756 - learning_rate: 5.0000e-04
# Epoch 24/100
# 102/102 - 50s - 489ms/step - accuracy: 0.8889 - loss: 0.4084 - val_accuracy: 0.7917 - val_loss: 0.5949 - learning_rate: 5.0000e-04
# Epoch 25/100
# 102/102 - 51s - 501ms/step - accuracy: 0.8836 - loss: 0.4161 - val_accuracy: 0.7167 - val_loss: 0.8671 - learning_rate: 5.0000e-04
# Epoch 26/100
# 102/102 - 52s - 510ms/step - accuracy: 0.8991 - loss: 0.3896 - val_accuracy: 0.8944 - val_loss: 0.3505 - learning_rate: 5.0000e-04
# Epoch 27/100
# 102/102 - 50s - 492ms/step - accuracy: 0.8889 - loss: 0.4018 - val_accuracy: 0.7611 - val_loss: 0.8533 - learning_rate: 5.0000e-04
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 102/102 - 51s - 504ms/step - accuracy: 0.9040 - loss: 0.3685 - val_accuracy: 0.6778 - val_loss: 1.4246 - learning_rate: 5.0000e-04
# Epoch 29/100
# 102/102 - 50s - 487ms/step - accuracy: 0.9253 - loss: 0.3222 - val_accuracy: 0.7750 - val_loss: 0.8057 - learning_rate: 2.5000e-04
# Epoch 30/100
# 102/102 - 49s - 480ms/step - accuracy: 0.9265 - loss: 0.2942 - val_accuracy: 0.7222 - val_loss: 1.0084 - learning_rate: 2.5000e-04
# Epoch 31/100
#
# 🎯 New best val_acc: 0.9500
# 102/102 - 47s - 460ms/step - accuracy: 0.9290 - loss: 0.3096 - val_accuracy: 0.9500 - val_loss: 0.2570 - learning_rate: 2.5000e-04
# Epoch 32/100
# 102/102 - 48s - 469ms/step - accuracy: 0.9265 - loss: 0.3031 - val_accuracy: 0.8722 - val_loss: 0.4424 - learning_rate: 2.5000e-04
# Epoch 33/100
# 102/102 - 48s - 469ms/step - accuracy: 0.9309 - loss: 0.2979 - val_accuracy: 0.7194 - val_loss: 0.9678 - learning_rate: 2.5000e-04
# Epoch 34/100
# 102/102 - 50s - 485ms/step - accuracy: 0.9253 - loss: 0.3048 - val_accuracy: 0.9250 - val_loss: 0.3130 - learning_rate: 2.5000e-04
# Epoch 35/100
# 102/102 - 49s - 481ms/step - accuracy: 0.9296 - loss: 0.3097 - val_accuracy: 0.9111 - val_loss: 0.2985 - learning_rate: 2.5000e-04
# Epoch 36/100
# 102/102 - 49s - 482ms/step - accuracy: 0.9219 - loss: 0.3170 - val_accuracy: 0.9361 - val_loss: 0.2534 - learning_rate: 2.5000e-04
# Epoch 37/100
# 102/102 - 49s - 477ms/step - accuracy: 0.9244 - loss: 0.3153 - val_accuracy: 0.7306 - val_loss: 0.9825 - learning_rate: 2.5000e-04
# Epoch 38/100
# 102/102 - 47s - 462ms/step - accuracy: 0.9383 - loss: 0.2534 - val_accuracy: 0.9444 - val_loss: 0.2615 - learning_rate: 2.5000e-04
# Epoch 39/100
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 102/102 - 49s - 476ms/step - accuracy: 0.9296 - loss: 0.2831 - val_accuracy: 0.8806 - val_loss: 0.3717 - learning_rate: 2.5000e-04
# Epoch 40/100
# 102/102 - 47s - 465ms/step - accuracy: 0.9336 - loss: 0.2733 - val_accuracy: 0.9333 - val_loss: 0.2472 - learning_rate: 1.2500e-04
# Epoch 41/100
# 102/102 - 49s - 483ms/step - accuracy: 0.9485 - loss: 0.2420 - val_accuracy: 0.8694 - val_loss: 0.4144 - learning_rate: 1.2500e-04
# Epoch 42/100
#
# 🎯 New best val_acc: 0.9639
# 102/102 - 48s - 469ms/step - accuracy: 0.9481 - loss: 0.2398 - val_accuracy: 0.9639 - val_loss: 0.1910 - learning_rate: 1.2500e-04
# Epoch 43/100
# 102/102 - 48s - 466ms/step - accuracy: 0.9500 - loss: 0.2381 - val_accuracy: 0.9611 - val_loss: 0.1951 - learning_rate: 1.2500e-04
# Epoch 44/100
# 102/102 - 47s - 463ms/step - accuracy: 0.9531 - loss: 0.2201 - val_accuracy: 0.9639 - val_loss: 0.1668 - learning_rate: 1.2500e-04
# Epoch 45/100
# 102/102 - 47s - 460ms/step - accuracy: 0.9485 - loss: 0.2266 - val_accuracy: 0.9611 - val_loss: 0.1965 - learning_rate: 1.2500e-04
# Epoch 46/100
#
# 🎯 New best val_acc: 0.9667
# 102/102 - 47s - 459ms/step - accuracy: 0.9497 - loss: 0.2184 - val_accuracy: 0.9667 - val_loss: 0.1622 - learning_rate: 1.2500e-04
# Epoch 47/100
#
# 🎯 New best val_acc: 0.9694
# 102/102 - 46s - 454ms/step - accuracy: 0.9512 - loss: 0.2284 - val_accuracy: 0.9694 - val_loss: 0.1502 - learning_rate: 1.2500e-04
# Epoch 48/100
# 102/102 - 47s - 462ms/step - accuracy: 0.9469 - loss: 0.2329 - val_accuracy: 0.9333 - val_loss: 0.3119 - learning_rate: 1.2500e-04
# Epoch 49/100
# 102/102 - 47s - 464ms/step - accuracy: 0.9522 - loss: 0.2265 - val_accuracy: 0.9139 - val_loss: 0.3282 - learning_rate: 1.2500e-04
# Epoch 50/100
# 102/102 - 47s - 459ms/step - accuracy: 0.9605 - loss: 0.1988 - val_accuracy: 0.9639 - val_loss: 0.2111 - learning_rate: 1.2500e-04
# Epoch 51/100
# 102/102 - 46s - 454ms/step - accuracy: 0.9534 - loss: 0.2175 - val_accuracy: 0.9472 - val_loss: 0.2849 - learning_rate: 1.2500e-04
# Epoch 52/100
# 102/102 - 47s - 457ms/step - accuracy: 0.9478 - loss: 0.2374 - val_accuracy: 0.9611 - val_loss: 0.1550 - learning_rate: 1.2500e-04
# Epoch 53/100
# 102/102 - 47s - 465ms/step - accuracy: 0.9546 - loss: 0.2192 - val_accuracy: 0.9611 - val_loss: 0.1689 - learning_rate: 1.2500e-04
# Epoch 54/100
# 102/102 - 47s - 457ms/step - accuracy: 0.9562 - loss: 0.2173 - val_accuracy: 0.9611 - val_loss: 0.1605 - learning_rate: 1.2500e-04
# Epoch 55/100
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 102/102 - 47s - 457ms/step - accuracy: 0.9540 - loss: 0.2180 - val_accuracy: 0.9472 - val_loss: 0.2464 - learning_rate: 1.2500e-04
# Epoch 56/100
# 102/102 - 48s - 473ms/step - accuracy: 0.9639 - loss: 0.1880 - val_accuracy: 0.9611 - val_loss: 0.1689 - learning_rate: 6.2500e-05
# Epoch 57/100
# 102/102 - 46s - 456ms/step - accuracy: 0.9651 - loss: 0.1933 - val_accuracy: 0.9611 - val_loss: 0.1918 - learning_rate: 6.2500e-05
# Epoch 58/100
# 102/102 - 46s - 451ms/step - accuracy: 0.9651 - loss: 0.1949 - val_accuracy: 0.9611 - val_loss: 0.2069 - learning_rate: 6.2500e-05
# Epoch 59/100
# 102/102 - 46s - 449ms/step - accuracy: 0.9636 - loss: 0.1973 - val_accuracy: 0.9667 - val_loss: 0.1572 - learning_rate: 6.2500e-05
# Epoch 60/100
# 102/102 - 46s - 451ms/step - accuracy: 0.9633 - loss: 0.1923 - val_accuracy: 0.9611 - val_loss: 0.1949 - learning_rate: 6.2500e-05
# Epoch 61/100
# 102/102 - 46s - 449ms/step - accuracy: 0.9639 - loss: 0.1854 - val_accuracy: 0.9667 - val_loss: 0.1841 - learning_rate: 6.2500e-05
# Epoch 62/100
#
# 🎯 New best val_acc: 0.9778
# 102/102 - 46s - 449ms/step - accuracy: 0.9633 - loss: 0.1831 - val_accuracy: 0.9778 - val_loss: 0.1433 - learning_rate: 6.2500e-05
# Epoch 63/100
# 102/102 - 48s - 467ms/step - accuracy: 0.9642 - loss: 0.1893 - val_accuracy: 0.9611 - val_loss: 0.1956 - learning_rate: 6.2500e-05
# Epoch 64/100
# 102/102 - 47s - 458ms/step - accuracy: 0.9636 - loss: 0.1820 - val_accuracy: 0.9556 - val_loss: 0.2592 - learning_rate: 6.2500e-05
# Epoch 65/100
# 102/102 - 46s - 449ms/step - accuracy: 0.9617 - loss: 0.1970 - val_accuracy: 0.9417 - val_loss: 0.2571 - learning_rate: 6.2500e-05
# Epoch 66/100
# 102/102 - 46s - 448ms/step - accuracy: 0.9654 - loss: 0.1979 - val_accuracy: 0.9278 - val_loss: 0.3189 - learning_rate: 6.2500e-05
# Epoch 67/100
# 102/102 - 46s - 451ms/step - accuracy: 0.9667 - loss: 0.1878 - val_accuracy: 0.9278 - val_loss: 0.3216 - learning_rate: 6.2500e-05
# Epoch 68/100
# 102/102 - 46s - 455ms/step - accuracy: 0.9636 - loss: 0.1799 - val_accuracy: 0.9694 - val_loss: 0.1588 - learning_rate: 6.2500e-05
# Epoch 69/100
# 102/102 - 47s - 465ms/step - accuracy: 0.9688 - loss: 0.1797 - val_accuracy: 0.9667 - val_loss: 0.1625 - learning_rate: 6.2500e-05
# Epoch 70/100
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 102/102 - 48s - 473ms/step - accuracy: 0.9716 - loss: 0.1681 - val_accuracy: 0.9500 - val_loss: 0.2550 - learning_rate: 6.2500e-05
# Epoch 71/100
# 102/102 - 47s - 461ms/step - accuracy: 0.9741 - loss: 0.1611 - val_accuracy: 0.9667 - val_loss: 0.1919 - learning_rate: 3.1250e-05
# Epoch 72/100
# 102/102 - 47s - 461ms/step - accuracy: 0.9710 - loss: 0.1680 - val_accuracy: 0.9583 - val_loss: 0.2068 - learning_rate: 3.1250e-05
# Epoch 73/100
# 102/102 - 47s - 464ms/step - accuracy: 0.9688 - loss: 0.1735 - val_accuracy: 0.9583 - val_loss: 0.1933 - learning_rate: 3.1250e-05
# Epoch 74/100
# 102/102 - 47s - 458ms/step - accuracy: 0.9719 - loss: 0.1679 - val_accuracy: 0.9611 - val_loss: 0.1703 - learning_rate: 3.1250e-05
# Epoch 75/100
# 102/102 - 47s - 459ms/step - accuracy: 0.9676 - loss: 0.1704 - val_accuracy: 0.9694 - val_loss: 0.1507 - learning_rate: 3.1250e-05
# Epoch 76/100
# 102/102 - 47s - 462ms/step - accuracy: 0.9707 - loss: 0.1727 - val_accuracy: 0.9611 - val_loss: 0.1760 - learning_rate: 3.1250e-05
# Epoch 77/100
# 102/102 - 49s - 477ms/step - accuracy: 0.9713 - loss: 0.1725 - val_accuracy: 0.9611 - val_loss: 0.1781 - learning_rate: 3.1250e-05
# Epoch 78/100
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 102/102 - 47s - 457ms/step - accuracy: 0.9657 - loss: 0.1828 - val_accuracy: 0.9639 - val_loss: 0.1714 - learning_rate: 3.1250e-05
# Epoch 79/100
# 102/102 - 47s - 464ms/step - accuracy: 0.9670 - loss: 0.1692 - val_accuracy: 0.9639 - val_loss: 0.1774 - learning_rate: 1.5625e-05
# Epoch 80/100
# 102/102 - 49s - 479ms/step - accuracy: 0.9701 - loss: 0.1657 - val_accuracy: 0.9639 - val_loss: 0.1834 - learning_rate: 1.5625e-05
# Epoch 81/100
# 102/102 - 50s - 490ms/step - accuracy: 0.9704 - loss: 0.1689 - val_accuracy: 0.9639 - val_loss: 0.1836 - learning_rate: 1.5625e-05
# Epoch 82/100
# 102/102 - 46s - 454ms/step - accuracy: 0.9633 - loss: 0.1821 - val_accuracy: 0.9722 - val_loss: 0.1666 - learning_rate: 1.5625e-05
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 62.
#
# ======================================================================
# MODEL EVALUATION
# ======================================================================
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9844 - loss: 0.1365
#
# 📊 Validation Results:
#    Accuracy: 0.9778
#    Loss: 0.1433
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 416ms/step - accuracy: 0.9856 - loss: 0.1077
#
# 🎯 Test Results:
#    Accuracy: 0.9825
#    Loss: 0.1198
#
# ======================================================================
# DETAILED METRICS
# ======================================================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       1.00      0.96      0.98        50
# Bacterial Canker       0.96      1.00      0.98        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       1.00      1.00      1.00        50
#       Gall Midge       0.98      0.98      0.98        50
#          Healthy       1.00      1.00      1.00        50
#   Powdery Mildew       0.94      0.98      0.96        50
#      Sooty Mould       0.98      0.94      0.96        50
#
#         accuracy                           0.98       400
#        macro avg       0.98      0.98      0.98       400
#     weighted avg       0.98      0.98      0.98       400
#
#
# 📊 Summary Metrics:
#    Precision: 0.9829
#    Recall: 0.9825
#    F1-Score: 0.9825
#
# === Generating Visualizations ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37/2025838810.py in <cell line: 0>()
#     369 for i, cls in enumerate(classes):
#     370     mask = (y_true_labels == i)
# --> 371     if mask.sum() > 0:
#     372         class_acc = (y_pred_labels[mask] == y_true_labels[mask]).mean()
#     373         class_accuracies[cls] = class_acc
#
# AttributeError: 'bool' object has no attribute 'sum'
