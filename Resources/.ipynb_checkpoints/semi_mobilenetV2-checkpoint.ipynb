# %%
# -*- coding: utf-8 -*-
"""Semi-Supervised Mango Leaf Classification with Pseudo-Labeling"""

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download aryashah2k/mango-leaf-disease-dataset

import os
import numpy as np
import pandas as pd
import random
import shutil
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import DenseNet121,MobileNetV2,VGG16,ResNet101
from tensorflow.keras.utils import image_dataset_from_directory, load_img, img_to_array
import matplotlib.pyplot as plt

"""# Step 1: Split Data into Train (80%), Validation (10%), Test (10%)"""

import kagglehub

# Paths
source_dir = kagglehub.dataset_download("aryashah2k/mango-leaf-disease-dataset")
base_dir = '/content/semi_supervised_data/'

# Create main directories
for split in ['train', 'validation', 'test']:
    os.makedirs(os.path.join(base_dir, split), exist_ok=True)

classes = [c for c in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, c))]

# Create class subdirectories
for cls in classes:
    for split in ['train', 'validation', 'test']:
        os.makedirs(os.path.join(base_dir, split, cls), exist_ok=True)

# Split data: 80% train, 10% validation, 10% test
def split_data():
    for cls in classes:
        class_dir = os.path.join(source_dir, cls)
        if os.path.isdir(class_dir):
            images = [img for img in os.listdir(class_dir) if img.endswith(('.jpg', '.jpeg', '.png'))]
            random.shuffle(images)

            total = len(images)
            train_size = int(0.8 * total)
            val_size = int(0.1 * total)

            train_images = images[:train_size]
            val_images = images[train_size:train_size + val_size]
            test_images = images[train_size + val_size:]

            # Copy images
            for image in train_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'train', cls, image))
            for image in val_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'validation', cls, image))
            for image in test_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'test', cls, image))

split_data()
print("✅ Data split into 80% train, 10% validation, 10% test")

"""# Step 2: Split Train Data into Labeled (25%) and Unlabeled (75%)"""

labeled_dir = '/content/semi_supervised_data/labeled/'
unlabeled_dir = '/content/semi_supervised_data/unlabeled/'

# Create directories
for cls in classes:
    os.makedirs(os.path.join(labeled_dir, cls), exist_ok=True)
    os.makedirs(os.path.join(unlabeled_dir, cls), exist_ok=True)

def split_labeled_unlabeled():
    train_dir = os.path.join(base_dir, 'train')

    for cls in classes:
        class_dir = os.path.join(train_dir, cls)
        images = [img for img in os.listdir(class_dir) if img.endswith(('.jpg', '.jpeg', '.png'))]
        random.shuffle(images)

        labeled_size = int(0.25 * len(images))
        labeled_images = images[:labeled_size]
        unlabeled_images = images[labeled_size:]

        # Copy labeled images
        for image in labeled_images:
            shutil.copy2(os.path.join(class_dir, image),
                       os.path.join(labeled_dir, cls, image))

        # Copy unlabeled images
        for image in unlabeled_images:
            shutil.copy2(os.path.join(class_dir, image),
                       os.path.join(unlabeled_dir, cls, image))

split_labeled_unlabeled()
print("✅ Train data split into 25% labeled and 75% unlabeled")

# Print dataset statistics
print("\n📊 Dataset Statistics:")
for split_name, split_path in [('Labeled', labeled_dir),
                                ('Unlabeled', unlabeled_dir),
                                ('Validation', os.path.join(base_dir, 'validation')),
                                ('Test', os.path.join(base_dir, 'test'))]:
    total = sum([len(os.listdir(os.path.join(split_path, cls))) for cls in classes])
    print(f"{split_name}: {total} images")

"""# Step 3: Load Datasets"""

img_size = (224, 224)
batch_size = 32

# Load labeled dataset
labeled_dataset = image_dataset_from_directory(
    labeled_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=True
)

# Load validation dataset
val_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=False
)

# Load test dataset
test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=False
)

class_names = labeled_dataset.class_names
num_classes = len(class_names)
print(f"\n🏷️ Classes: {class_names}")

"""# Step 4: Preprocess Datasets"""

def preprocess_data(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

labeled_dataset = labeled_dataset.map(preprocess_data)
val_dataset = val_dataset.map(preprocess_data)
test_dataset = test_dataset.map(preprocess_data)
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'
# Using Colab cache for faster access to the 'mango-leaf-disease-dataset' dataset.
# ✅ Data split into 80% train, 10% validation, 10% test
# ✅ Train data split into 25% labeled and 75% unlabeled
#
# 📊 Dataset Statistics:
# Labeled: 800 images
# Unlabeled: 2400 images
# Validation: 400 images
# Test: 400 images
# Found 800 files belonging to 8 classes.
# Found 400 files belonging to 8 classes.
# Found 400 files belonging to 8 classes.
#
# 🏷️ Classes: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']

# %%
"""# Step 5: Build Model"""
from keras import regularizers
from keras.layers import MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Conv2D, Dropout, Rescaling, Input
from keras.models import Sequential
def build_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze base model
    base_model.trainable = False

    # Create model
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.5),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

model = build_model()

"""# Step 6: Train on Labeled Data (30 Epochs)"""

print("\n🚀 Phase 1: Training on Labeled Data (30 epochs)")

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

history_labeled = model.fit(
    labeled_dataset,
    validation_data=val_dataset,
    epochs=30,
    callbacks=[early_stop, reduce_lr]
)


# Evaluate on validation set
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# 🚀 Phase 1: Training on Labeled Data (30 epochs)
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 43s 737ms/step - accuracy: 0.3463 - loss: 10.7677 - val_accuracy: 0.8975 - val_loss: 7.4622 - learning_rate: 0.0010
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.7501 - loss: 7.0791 - val_accuracy: 0.9475 - val_loss: 5.2872 - learning_rate: 0.0010
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.8627 - loss: 5.0680 - val_accuracy: 0.9425 - val_loss: 3.9797 - learning_rate: 0.0010
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9192 - loss: 3.8071 - val_accuracy: 0.9575 - val_loss: 3.0840 - learning_rate: 0.0010
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9296 - loss: 3.0129 - val_accuracy: 0.9700 - val_loss: 2.4624 - learning_rate: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9573 - loss: 2.3732 - val_accuracy: 0.9750 - val_loss: 1.9852 - learning_rate: 0.0010
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9718 - loss: 1.9344 - val_accuracy: 0.9500 - val_loss: 1.6937 - learning_rate: 0.0010
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9472 - loss: 1.6539 - val_accuracy: 0.9650 - val_loss: 1.4022 - learning_rate: 0.0010
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9584 - loss: 1.4018 - val_accuracy: 0.9775 - val_loss: 1.1887 - learning_rate: 0.0010
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9750 - loss: 1.1742 - val_accuracy: 0.9650 - val_loss: 1.0604 - learning_rate: 0.0010
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9785 - loss: 1.0245 - val_accuracy: 0.9775 - val_loss: 0.9173 - learning_rate: 0.0010
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9677 - loss: 0.9121 - val_accuracy: 0.9775 - val_loss: 0.8151 - learning_rate: 0.0010
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9805 - loss: 0.8034 - val_accuracy: 0.9625 - val_loss: 0.7325 - learning_rate: 0.0010
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9795 - loss: 0.7100 - val_accuracy: 0.9650 - val_loss: 0.6554 - learning_rate: 0.0010
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9790 - loss: 0.6413 - val_accuracy: 0.9650 - val_loss: 0.6109 - learning_rate: 0.0010
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9748 - loss: 0.5958 - val_accuracy: 0.9775 - val_loss: 0.5426 - learning_rate: 0.0010
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9718 - loss: 0.5621 - val_accuracy: 0.9825 - val_loss: 0.5111 - learning_rate: 0.0010
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9754 - loss: 0.5196 - val_accuracy: 0.9550 - val_loss: 0.5130 - learning_rate: 0.0010
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9789 - loss: 0.5064 - val_accuracy: 0.9550 - val_loss: 0.5254 - learning_rate: 0.0010
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9698 - loss: 0.4994 - val_accuracy: 0.9675 - val_loss: 0.4646 - learning_rate: 0.0010
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9744 - loss: 0.4653 - val_accuracy: 0.9825 - val_loss: 0.4294 - learning_rate: 0.0010
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9827 - loss: 0.4381 - val_accuracy: 0.9600 - val_loss: 0.4560 - learning_rate: 0.0010
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9714 - loss: 0.4481 - val_accuracy: 0.9700 - val_loss: 0.4133 - learning_rate: 0.0010
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9804 - loss: 0.4029 - val_accuracy: 0.9750 - val_loss: 0.3794 - learning_rate: 0.0010
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.9801 - loss: 0.4039 - val_accuracy: 0.9675 - val_loss: 0.4261 - learning_rate: 0.0010
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9785 - loss: 0.4068 - val_accuracy: 0.9750 - val_loss: 0.3981 - learning_rate: 0.0010
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9679 - loss: 0.4169 - val_accuracy: 0.9775 - val_loss: 0.3814 - learning_rate: 0.0010
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9748 - loss: 0.3972 - val_accuracy: 0.9825 - val_loss: 0.3659 - learning_rate: 0.0010
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9898 - loss: 0.3695 - val_accuracy: 0.9600 - val_loss: 0.4017 - learning_rate: 0.0010
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9709 - loss: 0.3895 - val_accuracy: 0.9750 - val_loss: 0.3707 - learning_rate: 0.0010
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9830 - loss: 0.3514

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_labeled.history["accuracy"], label="Training Accuracy for Labeled Data")
plt.plot(history_labeled.history["val_accuracy"], label="Validation Accuracy for Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_labeled.history["loss"], label="Training Loss for Labeled Data")
plt.plot(history_labeled.history["val_loss"], label="Validation Loss for Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
"""# Step 7: Generate Pseudo-Labels for Unlabeled Data"""

print("\n🔮 Generating Pseudo-Labels for Unlabeled Data...")

# Create pseudo-labeled directory
pseudo_labeled_dir = '/content/semi_supervised_data/pseudo_labeled/'
for cls in classes:
    os.makedirs(os.path.join(pseudo_labeled_dir, cls), exist_ok=True)

# Generate pseudo-labels with confidence threshold
confidence_threshold = 0.7

def generate_pseudo_labels():
    pseudo_count = 0

    for cls in classes:
        class_path = os.path.join(unlabeled_dir, cls)
        images = [img for img in os.listdir(class_path) if img.endswith(('.jpg', '.jpeg', '.png'))]

        for img_name in images:
            img_path = os.path.join(class_path, img_name)

            # Load and preprocess image
            img = load_img(img_path, target_size=img_size)
            img_array = img_to_array(img) / 255.0
            img_array = np.expand_dims(img_array, axis=0)

            # Predict
            predictions = model.predict(img_array, verbose=0)
            confidence = np.max(predictions)
            predicted_class_idx = np.argmax(predictions)
            predicted_class = class_names[predicted_class_idx]

            # Only use high-confidence predictions
            if confidence >= confidence_threshold:
                dest_path = os.path.join(pseudo_labeled_dir, predicted_class, img_name)
                shutil.copy2(img_path, dest_path)
                pseudo_count += 1

    return pseudo_count

pseudo_count = generate_pseudo_labels()
print(f"✅ Generated {pseudo_count} pseudo-labels (confidence >= {confidence_threshold})")

"""# Step 8: Merge Labeled and Pseudo-Labeled Data"""

merged_dir = '/content/semi_supervised_data/merged/'
for cls in classes:
    os.makedirs(os.path.join(merged_dir, cls), exist_ok=True)

def merge_datasets():
    # Copy labeled data
    for cls in classes:
        labeled_path = os.path.join(labeled_dir, cls)
        images = os.listdir(labeled_path)
        for img in images:
            shutil.copy2(os.path.join(labeled_path, img),
                       os.path.join(merged_dir, cls, img))

    # Copy pseudo-labeled data
    for cls in classes:
        pseudo_path = os.path.join(pseudo_labeled_dir, cls)
        if os.path.exists(pseudo_path):
            images = os.listdir(pseudo_path)
            for img in images:
                shutil.copy2(os.path.join(pseudo_path, img),
                           os.path.join(merged_dir, cls, f"pseudo_{img}"))

merge_datasets()

# Load merged dataset
merged_dataset = image_dataset_from_directory(
    merged_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=True
)
merged_dataset = merged_dataset.map(preprocess_data)

merged_count = sum([len(os.listdir(os.path.join(merged_dir, cls))) for cls in classes])
print(f"✅ Merged dataset created with {merged_count} images")

"""# Step 9: Train on Merged Data (100 Epochs)"""

print("\n🚀 Phase 2: Training on Merged Data (100 epochs)")

# Rebuild model or continue with existing
# Option 1: Continue with same model
# Option 2: Rebuild model (uncomment below)
# model = build_model()

history_merged = model.fit(
    merged_dataset,
    validation_data=val_dataset,
    epochs=100,
    callbacks=[early_stop, reduce_lr]
)

"""# Step 10: Final Evaluation"""

test_loss, test_acc = model.evaluate(test_dataset)
print(f"\n🎯 Final Test Accuracy: {test_acc * 100:.2f}%")

"""# Step 11: Plot Training History"""

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_merged.history["accuracy"], label="Training Accuracy for Unlabeled and Labeled Data")
plt.plot(history_merged.history["val_accuracy"], label="Validation Accuracy for Unlabeled and Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Training Accuracy - Semi-Supervised Learning')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_merged.history["loss"], label="Training Loss for Unlabeled and Labeled Data")
plt.plot(history_merged.history["val_loss"], label="Validation Loss for Unlabeled and Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Training Loss - Semi-Supervised Learning')
plt.legend()
plt.grid(True)
plt.show()
print(f"\n✅ After Labeled Training - Validation Accuracy: {test_acc * 100:.2f}%")
# Out:
# 🔮 Generating Pseudo-Labels for Unlabeled Data...
# ✅ Generated 2265 pseudo-labels (confidence >= 0.7)
# Found 3065 files belonging to 8 classes.
# ✅ Merged dataset created with 3065 images
#
# 🚀 Phase 2: Training on Merged Data (100 epochs)
# Epoch 1/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 168ms/step - accuracy: 0.9624 - loss: 0.4217 - val_accuracy: 0.9750 - val_loss: 0.4070 - learning_rate: 0.0010
# Epoch 2/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9470 - loss: 0.4662 - val_accuracy: 0.9700 - val_loss: 0.4117 - learning_rate: 0.0010
# Epoch 3/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9625 - loss: 0.4164 - val_accuracy: 0.9650 - val_loss: 0.4007 - learning_rate: 0.0010
# Epoch 4/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9562 - loss: 0.4337 - val_accuracy: 0.9750 - val_loss: 0.3715 - learning_rate: 0.0010
# Epoch 5/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.9592 - loss: 0.4022 - val_accuracy: 0.9700 - val_loss: 0.3870 - learning_rate: 0.0010
# Epoch 6/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9685 - loss: 0.4066 - val_accuracy: 0.9550 - val_loss: 0.3746 - learning_rate: 0.0010
# Epoch 7/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9668 - loss: 0.3942 - val_accuracy: 0.9425 - val_loss: 0.4571 - learning_rate: 0.0010
# Epoch 8/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.9601 - loss: 0.4058 - val_accuracy: 0.9500 - val_loss: 0.4136 - learning_rate: 0.0010
# Epoch 9/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9580 - loss: 0.4235 - val_accuracy: 0.9575 - val_loss: 0.4014 - learning_rate: 0.0010
# Epoch 10/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9655 - loss: 0.3728 - val_accuracy: 0.9875 - val_loss: 0.2976 - learning_rate: 5.0000e-04
# Epoch 11/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9801 - loss: 0.2953 - val_accuracy: 0.9700 - val_loss: 0.2711 - learning_rate: 5.0000e-04
# Epoch 12/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9824 - loss: 0.2656 - val_accuracy: 0.9725 - val_loss: 0.2757 - learning_rate: 5.0000e-04
# Epoch 13/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9783 - loss: 0.2667 - val_accuracy: 0.9725 - val_loss: 0.2630 - learning_rate: 5.0000e-04
# Epoch 14/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9858 - loss: 0.2472 - val_accuracy: 0.9750 - val_loss: 0.2523 - learning_rate: 5.0000e-04
# Epoch 15/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9772 - loss: 0.2570 - val_accuracy: 0.9875 - val_loss: 0.2370 - learning_rate: 5.0000e-04
# Epoch 16/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9845 - loss: 0.2440 - val_accuracy: 0.9675 - val_loss: 0.2523 - learning_rate: 5.0000e-04
# Epoch 17/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9837 - loss: 0.2341 - val_accuracy: 0.9675 - val_loss: 0.2670 - learning_rate: 5.0000e-04
# Epoch 18/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9880 - loss: 0.2290 - val_accuracy: 0.9775 - val_loss: 0.2427 - learning_rate: 5.0000e-04
# Epoch 19/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9869 - loss: 0.2303 - val_accuracy: 0.9700 - val_loss: 0.2480 - learning_rate: 5.0000e-04
# Epoch 20/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9834 - loss: 0.2342 - val_accuracy: 0.9750 - val_loss: 0.2542 - learning_rate: 5.0000e-04
# Epoch 21/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9855 - loss: 0.2270 - val_accuracy: 0.9775 - val_loss: 0.2242 - learning_rate: 2.5000e-04
# Epoch 22/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9913 - loss: 0.1999 - val_accuracy: 0.9775 - val_loss: 0.2180 - learning_rate: 2.5000e-04
# Epoch 23/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9884 - loss: 0.2020 - val_accuracy: 0.9750 - val_loss: 0.2122 - learning_rate: 2.5000e-04
# Epoch 24/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9916 - loss: 0.1911 - val_accuracy: 0.9725 - val_loss: 0.2088 - learning_rate: 2.5000e-04
# Epoch 25/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.9960 - loss: 0.1772 - val_accuracy: 0.9775 - val_loss: 0.2034 - learning_rate: 2.5000e-04
# Epoch 26/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9855 - loss: 0.1907 - val_accuracy: 0.9825 - val_loss: 0.2021 - learning_rate: 2.5000e-04
# Epoch 27/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9908 - loss: 0.1840 - val_accuracy: 0.9825 - val_loss: 0.1998 - learning_rate: 2.5000e-04
# Epoch 28/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9931 - loss: 0.1773 - val_accuracy: 0.9775 - val_loss: 0.1912 - learning_rate: 2.5000e-04
# Epoch 29/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9955 - loss: 0.1705 - val_accuracy: 0.9700 - val_loss: 0.2094 - learning_rate: 2.5000e-04
# Epoch 30/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9932 - loss: 0.1704 - val_accuracy: 0.9775 - val_loss: 0.1928 - learning_rate: 2.5000e-04
# Epoch 31/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.9950 - loss: 0.1671 - val_accuracy: 0.9750 - val_loss: 0.1975 - learning_rate: 2.5000e-04
# Epoch 32/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9865 - loss: 0.1806 - val_accuracy: 0.9750 - val_loss: 0.1999 - learning_rate: 2.5000e-04
# Epoch 33/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9921 - loss: 0.1787 - val_accuracy: 0.9750 - val_loss: 0.1988 - learning_rate: 2.5000e-04
# Epoch 34/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9919 - loss: 0.1753 - val_accuracy: 0.9800 - val_loss: 0.1906 - learning_rate: 1.2500e-04
# Epoch 35/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9940 - loss: 0.1589 - val_accuracy: 0.9800 - val_loss: 0.1856 - learning_rate: 1.2500e-04
# Epoch 36/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9958 - loss: 0.1588 - val_accuracy: 0.9775 - val_loss: 0.1839 - learning_rate: 1.2500e-04
# Epoch 37/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9968 - loss: 0.1533 - val_accuracy: 0.9775 - val_loss: 0.1857 - learning_rate: 1.2500e-04
# Epoch 38/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9956 - loss: 0.1528 - val_accuracy: 0.9775 - val_loss: 0.1840 - learning_rate: 1.2500e-04
# Epoch 39/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9937 - loss: 0.1552 - val_accuracy: 0.9750 - val_loss: 0.1814 - learning_rate: 1.2500e-04
# Epoch 40/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9941 - loss: 0.1594 - val_accuracy: 0.9800 - val_loss: 0.1808 - learning_rate: 1.2500e-04
# Epoch 41/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9951 - loss: 0.1539 - val_accuracy: 0.9750 - val_loss: 0.1774 - learning_rate: 1.2500e-04
# Epoch 42/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9922 - loss: 0.1575 - val_accuracy: 0.9825 - val_loss: 0.1762 - learning_rate: 1.2500e-04
# Epoch 43/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9968 - loss: 0.1487 - val_accuracy: 0.9775 - val_loss: 0.1759 - learning_rate: 1.2500e-04
# Epoch 44/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9983 - loss: 0.1441 - val_accuracy: 0.9775 - val_loss: 0.1781 - learning_rate: 1.2500e-04
# Epoch 45/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.9970 - loss: 0.1447 - val_accuracy: 0.9775 - val_loss: 0.1766 - learning_rate: 1.2500e-04
# Epoch 46/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9982 - loss: 0.1440 - val_accuracy: 0.9725 - val_loss: 0.1800 - learning_rate: 1.2500e-04
# Epoch 47/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9935 - loss: 0.1463 - val_accuracy: 0.9700 - val_loss: 0.1789 - learning_rate: 1.2500e-04
# Epoch 48/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.9946 - loss: 0.1428 - val_accuracy: 0.9825 - val_loss: 0.1725 - learning_rate: 1.2500e-04
# Epoch 49/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9971 - loss: 0.1466 - val_accuracy: 0.9800 - val_loss: 0.1783 - learning_rate: 1.2500e-04
# Epoch 50/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9951 - loss: 0.1436 - val_accuracy: 0.9850 - val_loss: 0.1693 - learning_rate: 1.2500e-04
# Epoch 51/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9952 - loss: 0.1496 - val_accuracy: 0.9850 - val_loss: 0.1716 - learning_rate: 1.2500e-04
# Epoch 52/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9946 - loss: 0.1462 - val_accuracy: 0.9750 - val_loss: 0.1734 - learning_rate: 1.2500e-04
# Epoch 53/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9962 - loss: 0.1419 - val_accuracy: 0.9700 - val_loss: 0.1736 - learning_rate: 1.2500e-04
# Epoch 54/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9947 - loss: 0.1461 - val_accuracy: 0.9850 - val_loss: 0.1664 - learning_rate: 1.2500e-04
# Epoch 55/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9914 - loss: 0.1510 - val_accuracy: 0.9750 - val_loss: 0.1760 - learning_rate: 1.2500e-04
# Epoch 56/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9959 - loss: 0.1388 - val_accuracy: 0.9800 - val_loss: 0.1677 - learning_rate: 1.2500e-04
# Epoch 57/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9945 - loss: 0.1484 - val_accuracy: 0.9800 - val_loss: 0.1699 - learning_rate: 1.2500e-04
# Epoch 58/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.9958 - loss: 0.1377 - val_accuracy: 0.9775 - val_loss: 0.1681 - learning_rate: 1.2500e-04
# Epoch 59/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9970 - loss: 0.1376 - val_accuracy: 0.9700 - val_loss: 0.1757 - learning_rate: 1.2500e-04
# Epoch 60/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9921 - loss: 0.1389 - val_accuracy: 0.9750 - val_loss: 0.1666 - learning_rate: 6.2500e-05
# Epoch 61/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9975 - loss: 0.1323 - val_accuracy: 0.9775 - val_loss: 0.1675 - learning_rate: 6.2500e-05
# Epoch 62/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.9966 - loss: 0.1327 - val_accuracy: 0.9725 - val_loss: 0.1655 - learning_rate: 6.2500e-05
# Epoch 63/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9988 - loss: 0.1259 - val_accuracy: 0.9800 - val_loss: 0.1592 - learning_rate: 6.2500e-05
# Epoch 64/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9977 - loss: 0.1300 - val_accuracy: 0.9725 - val_loss: 0.1659 - learning_rate: 6.2500e-05
# Epoch 65/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9987 - loss: 0.1282 - val_accuracy: 0.9775 - val_loss: 0.1605 - learning_rate: 6.2500e-05
# Epoch 66/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9968 - loss: 0.1288 - val_accuracy: 0.9825 - val_loss: 0.1582 - learning_rate: 6.2500e-05
# Epoch 67/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9975 - loss: 0.1278 - val_accuracy: 0.9800 - val_loss: 0.1584 - learning_rate: 6.2500e-05
# Epoch 68/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.9972 - loss: 0.1258 - val_accuracy: 0.9775 - val_loss: 0.1624 - learning_rate: 6.2500e-05
# Epoch 69/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9984 - loss: 0.1227 - val_accuracy: 0.9800 - val_loss: 0.1615 - learning_rate: 6.2500e-05
# Epoch 70/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9954 - loss: 0.1304 - val_accuracy: 0.9750 - val_loss: 0.1610 - learning_rate: 6.2500e-05
# Epoch 71/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9976 - loss: 0.1256 - val_accuracy: 0.9725 - val_loss: 0.1613 - learning_rate: 6.2500e-05
# Epoch 72/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9978 - loss: 0.1241 - val_accuracy: 0.9750 - val_loss: 0.1588 - learning_rate: 3.1250e-05
# Epoch 73/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9950 - loss: 0.1254 - val_accuracy: 0.9775 - val_loss: 0.1577 - learning_rate: 3.1250e-05
# Epoch 74/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9973 - loss: 0.1250 - val_accuracy: 0.9750 - val_loss: 0.1582 - learning_rate: 3.1250e-05
# Epoch 75/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9994 - loss: 0.1197 - val_accuracy: 0.9750 - val_loss: 0.1556 - learning_rate: 3.1250e-05
# Epoch 76/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9965 - loss: 0.1225 - val_accuracy: 0.9750 - val_loss: 0.1557 - learning_rate: 3.1250e-05
# Epoch 77/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9983 - loss: 0.1198 - val_accuracy: 0.9750 - val_loss: 0.1585 - learning_rate: 3.1250e-05
# Epoch 78/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9973 - loss: 0.1201 - val_accuracy: 0.9775 - val_loss: 0.1563 - learning_rate: 3.1250e-05
# Epoch 79/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9946 - loss: 0.1226 - val_accuracy: 0.9750 - val_loss: 0.1559 - learning_rate: 3.1250e-05
# Epoch 80/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.9987 - loss: 0.1185 - val_accuracy: 0.9750 - val_loss: 0.1557 - learning_rate: 3.1250e-05
# Epoch 81/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9992 - loss: 0.1172 - val_accuracy: 0.9775 - val_loss: 0.1561 - learning_rate: 1.5625e-05
# Epoch 82/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9967 - loss: 0.1195 - val_accuracy: 0.9750 - val_loss: 0.1558 - learning_rate: 1.5625e-05
# Epoch 83/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9991 - loss: 0.1182 - val_accuracy: 0.9750 - val_loss: 0.1548 - learning_rate: 1.5625e-05
# Epoch 84/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9992 - loss: 0.1186 - val_accuracy: 0.9750 - val_loss: 0.1556 - learning_rate: 1.5625e-05
# Epoch 85/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9981 - loss: 0.1164 - val_accuracy: 0.9775 - val_loss: 0.1546 - learning_rate: 1.5625e-05
# Epoch 86/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9990 - loss: 0.1162 - val_accuracy: 0.9750 - val_loss: 0.1570 - learning_rate: 1.5625e-05
# Epoch 87/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9970 - loss: 0.1177 - val_accuracy: 0.9750 - val_loss: 0.1571 - learning_rate: 1.5625e-05
# Epoch 88/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9972 - loss: 0.1214 - val_accuracy: 0.9750 - val_loss: 0.1549 - learning_rate: 1.5625e-05
# Epoch 89/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9961 - loss: 0.1196 - val_accuracy: 0.9750 - val_loss: 0.1545 - learning_rate: 1.5625e-05
# Epoch 90/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9988 - loss: 0.1172 - val_accuracy: 0.9750 - val_loss: 0.1571 - learning_rate: 1.5625e-05
# Epoch 91/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9995 - loss: 0.1152 - val_accuracy: 0.9750 - val_loss: 0.1556 - learning_rate: 1.5625e-05
# Epoch 92/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9982 - loss: 0.1143 - val_accuracy: 0.9750 - val_loss: 0.1548 - learning_rate: 1.5625e-05
# Epoch 93/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9974 - loss: 0.1177 - val_accuracy: 0.9775 - val_loss: 0.1532 - learning_rate: 1.5625e-05
# Epoch 94/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9996 - loss: 0.1160 - val_accuracy: 0.9750 - val_loss: 0.1537 - learning_rate: 1.5625e-05
# Epoch 95/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9963 - loss: 0.1184 - val_accuracy: 0.9775 - val_loss: 0.1537 - learning_rate: 1.5625e-05
# Epoch 96/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9995 - loss: 0.1119 - val_accuracy: 0.9725 - val_loss: 0.1560 - learning_rate: 1.5625e-05
# Epoch 97/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9972 - loss: 0.1174 - val_accuracy: 0.9750 - val_loss: 0.1542 - learning_rate: 1.5625e-05
# Epoch 98/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9978 - loss: 0.1166 - val_accuracy: 0.9750 - val_loss: 0.1516 - learning_rate: 1.5625e-05
# Epoch 99/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.9978 - loss: 0.1151 - val_accuracy: 0.9750 - val_loss: 0.1524 - learning_rate: 1.5625e-05
# Epoch 100/100
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9971 - loss: 0.1181 - val_accuracy: 0.9750 - val_loss: 0.1527 - learning_rate: 1.5625e-05
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9922 - loss: 0.1221
#
# 🎯 Final Test Accuracy: 98.50%
# ✅ After Labeled Training - Validation Accuracy: 98.50%

# %%
"""# Step 12: Confusion Matrix"""

y_true = []
y_pred = []

for images, labels in test_dataset:
    predictions = model.predict(images, verbose=0)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.title("Confusion Matrix - Semi-Supervised Learning", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Recover class names (if .class_names lost)
test_dir = os.path.join(base_dir, 'test')
class_names = sorted(os.listdir(test_dir))

# Collect true labels
y_true = np.concatenate([y for x, y in test_dataset], axis=0)

# Predict
predictions = model.predict(test_dataset)
y_pred = np.argmax(predictions, axis=1)

# Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 379ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       1.00      0.98      0.99        50
# Bacterial Canker       1.00      1.00      1.00        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       1.00      1.00      1.00        50
#       Gall Midge       0.98      1.00      0.99        50
#          Healthy       0.98      1.00      0.99        50
#   Powdery Mildew       0.96      0.96      0.96        50
#      Sooty Mould       0.96      0.94      0.95        50
#
#         accuracy                           0.98       400
#        macro avg       0.98      0.98      0.98       400
#     weighted avg       0.98      0.98      0.98       400
