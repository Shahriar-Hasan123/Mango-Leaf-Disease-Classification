# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Conv2D, Dropout, Rescaling, Input
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Configuration
data_path = "/kaggle/input/mango-leaf-disease-dataset"
img_size = (224, 224)
batch_size = 32
mode = "rgb"
epochs = 100
SEED = 42

# Create dataframes
def df_maker(path):
    file_paths = []
    labels = []

    folds = os.listdir(path)
    for fold in folds:
        fold_path = os.path.join(path, fold)
        file_list = os.listdir(fold_path)
        for file in file_list:
            file_path = os.path.join(fold_path, file)
            file_paths.append(file_path)
            labels.append(fold)

    file_series = pd.Series(file_paths, name="file_paths")
    label_series = pd.Series(labels, name="labels")

    df = pd.concat([file_series, label_series], axis=1)
    return df

# Create dataframe
df = df_maker(data_path)

# Split data
train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=SEED, stratify=df["labels"])
test_df, val_df = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=SEED, stratify=test_df["labels"])

# Data generators
train_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()
val_datagen = ImageDataGenerator()

train_data = train_datagen.flow_from_dataframe(
    train_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
)
test_data = test_datagen.flow_from_dataframe(
    test_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=False,
)
val_data = val_datagen.flow_from_dataframe(
    val_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
)

# Get class names
class_names = list(train_data.class_indices.keys())
num_classes = len(class_names)

# Model configurations
MODEL_CONFIG = {
    
    'InceptionV3': {
        'model_class': tf.keras.applications.InceptionV3,
        'preprocess_input': tf.keras.applications.inception_v3.preprocess_input,
        'layers_to_unfreeze': 25,
        'input_shape': (224, 224, 3)
    },
    'EfficientNetB0': {
        'model_class': tf.keras.applications.EfficientNetB0,
        'preprocess_input': tf.keras.applications.efficientnet.preprocess_input,
        'layers_to_unfreeze': 20,
        'input_shape': (224, 224, 3)
    },
    'NASNetMobile': {
        'model_class': tf.keras.applications.NASNetMobile,
        'preprocess_input': tf.keras.applications.nasnet.preprocess_input,
        'layers_to_unfreeze': 10,
        'input_shape': (224, 224, 3)
    }
}


# Function to create model
def create_model(model_name):
    config = MODEL_CONFIG[model_name]
    
    # Create base model
    base_model = config['model_class'](
        weights='imagenet',
        include_top=False,
        input_shape=config['input_shape']
    )
    
    # Freeze base model
    base_model.trainable = False
    
    # Create model
    model = Sequential([
        Input(shape=config['input_shape']),
        base_model,
        GlobalAveragePooling2D(),
        Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.5),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    
    # Compile model
    model.compile(
        optimizer=Adamax(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model, base_model

# Function to train model
def train_model(model, model_name, epochs=25):
    # Create callbacks
    checkpoint = ModelCheckpoint(
        f'{model_name}_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max'
    )
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        mode='max'
    )
    
    # Train model
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        callbacks=[checkpoint, early_stopping]
    )
    
    return history

# Function to evaluate model
def evaluate_model(model, model_name):
    # Evaluate on test data
    test_loss, test_acc = model.evaluate(test_data)
    print(f"{model_name} Test Accuracy: {test_acc:.4f}")
    
    # Make predictions
    predictions = model.predict(test_data)
    y_pred = np.argmax(predictions, axis=1)
    y_true = test_data.classes
    
    # Print classification report
    print(f"\n{model_name} Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    # Plot confusion matrix
    plt.figure(figsize=(12, 9))
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.Blues)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.title(f"{model_name} Confusion Matrix")
    plt.show()
    
    return test_acc, y_pred, y_true

# Function to plot training history
def plot_history(history, model_name):
    # Create dataframe from history
    vals = pd.DataFrame(history.history)
    vals = vals.rename(columns={
        "loss": "Train Loss",
        "val_loss": "Validation Loss",
        "accuracy": "Train Accuracy",
        "val_accuracy": "Validation Accuracy"
    })
    
    # Plot accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(vals["Train Accuracy"], label="Training Accuracy")
    plt.plot(vals["Validation Accuracy"], label="Validation Accuracy")
    plt.title(f"{model_name} Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(vals["Train Loss"], label="Training Loss")
    plt.plot(vals["Validation Loss"], label="Validation Loss")
    plt.title(f"{model_name} Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.tight_layout()
    plt.show()



# Train and evaluate models
results = {}
models_to_train = ['InceptionV3', 'EfficientNetB0', 'NASNetMobile']

for model_name in models_to_train:
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    # Create model
    model, base_model = create_model(model_name)
    model.summary()
    
    # Train model
    history = train_model(model, model_name, epochs)
    
    # Plot training history
    plot_history(history, model_name)
    
    # Evaluate model
    test_acc, y_pred, y_true = evaluate_model(model, model_name)
# Out:
# Found 3200 validated image filenames belonging to 8 classes.
# Found 400 validated image filenames belonging to 8 classes.
# Found 400 validated image filenames belonging to 8 classes.
#
# ==================================================
# Training InceptionV3
# ==================================================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,361,256 (85.30 MB)
#  Trainable params: 558,472 (2.13 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761382841.908549      99 service.cc:148] XLA service 0x7ea02404de80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761382841.909436      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761382841.909462      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761382843.759819      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/100 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - accuracy: 0.1953 - loss: 73.1023
# I0000 00:00:1761382851.797416      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 57s 359ms/step - accuracy: 0.1712 - loss: 26.5064 - val_accuracy: 0.2500 - val_loss: 8.9887
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.2063 - loss: 8.9238 - val_accuracy: 0.3325 - val_loss: 8.3893
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.2256 - loss: 8.3923 - val_accuracy: 0.4200 - val_loss: 7.8163
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.2876 - loss: 7.9255 - val_accuracy: 0.4300 - val_loss: 7.3855
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.3320 - loss: 7.4841 - val_accuracy: 0.5050 - val_loss: 6.9984
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.3851 - loss: 7.0896 - val_accuracy: 0.4975 - val_loss: 6.6689
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.3776 - loss: 6.7717 - val_accuracy: 0.4875 - val_loss: 6.3774
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4189 - loss: 6.4321 - val_accuracy: 0.5225 - val_loss: 6.0916
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.4222 - loss: 6.1941 - val_accuracy: 0.5675 - val_loss: 5.7561
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.4212 - loss: 5.9169 - val_accuracy: 0.5700 - val_loss: 5.4723
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.4428 - loss: 5.6498 - val_accuracy: 0.5675 - val_loss: 5.3183
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4358 - loss: 5.4234 - val_accuracy: 0.5775 - val_loss: 4.9751
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.4633 - loss: 5.1200 - val_accuracy: 0.5625 - val_loss: 4.7981
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.4516 - loss: 4.9470 - val_accuracy: 0.5550 - val_loss: 4.5776
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.4756 - loss: 4.7450 - val_accuracy: 0.5850 - val_loss: 4.3038
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - accuracy: 0.4860 - loss: 4.4919 - val_accuracy: 0.5925 - val_loss: 4.1348
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.4678 - loss: 4.3100 - val_accuracy: 0.5875 - val_loss: 3.9400
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.4834 - loss: 4.0945 - val_accuracy: 0.6100 - val_loss: 3.7544
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.4980 - loss: 3.8731 - val_accuracy: 0.5825 - val_loss: 3.5205
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.5106 - loss: 3.6695 - val_accuracy: 0.6250 - val_loss: 3.3388
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.5201 - loss: 3.5214 - val_accuracy: 0.6425 - val_loss: 3.1640
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.5081 - loss: 3.3699 - val_accuracy: 0.6125 - val_loss: 3.0435
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.4919 - loss: 3.2349 - val_accuracy: 0.6450 - val_loss: 2.8754
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4975 - loss: 3.0848 - val_accuracy: 0.6500 - val_loss: 2.7099
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5172 - loss: 2.9289 - val_accuracy: 0.6475 - val_loss: 2.6175
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.5311 - loss: 2.8106 - val_accuracy: 0.6575 - val_loss: 2.4951
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5406 - loss: 2.6654 - val_accuracy: 0.6325 - val_loss: 2.4422
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.5162 - loss: 2.5801 - val_accuracy: 0.6550 - val_loss: 2.2822
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.5340 - loss: 2.4522 - val_accuracy: 0.6550 - val_loss: 2.2264
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5465 - loss: 2.3534 - val_accuracy: 0.6475 - val_loss: 2.0981
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.5575 - loss: 2.2435 - val_accuracy: 0.6525 - val_loss: 1.9818
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.5523 - loss: 2.1561 - val_accuracy: 0.6900 - val_loss: 1.8885
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.5587 - loss: 2.1015 - val_accuracy: 0.6350 - val_loss: 1.8294
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5605 - loss: 2.0271 - val_accuracy: 0.6400 - val_loss: 1.7409
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5821 - loss: 1.8917 - val_accuracy: 0.6725 - val_loss: 1.6877
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.5793 - loss: 1.8398 - val_accuracy: 0.6450 - val_loss: 1.6414
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.5727 - loss: 1.8043 - val_accuracy: 0.6225 - val_loss: 1.5905
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.5860 - loss: 1.7263 - val_accuracy: 0.6950 - val_loss: 1.5127
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.5546 - loss: 1.7079 - val_accuracy: 0.6650 - val_loss: 1.4549
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6005 - loss: 1.6186 - val_accuracy: 0.6375 - val_loss: 1.4332
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.5826 - loss: 1.5795 - val_accuracy: 0.6800 - val_loss: 1.3633
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.5973 - loss: 1.5048 - val_accuracy: 0.6675 - val_loss: 1.2789
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6002 - loss: 1.4525 - val_accuracy: 0.6650 - val_loss: 1.3866
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.5971 - loss: 1.4121 - val_accuracy: 0.7000 - val_loss: 1.2542
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6221 - loss: 1.3538 - val_accuracy: 0.6875 - val_loss: 1.2170
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.6072 - loss: 1.3519 - val_accuracy: 0.7025 - val_loss: 1.1769
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6114 - loss: 1.3023 - val_accuracy: 0.6650 - val_loss: 1.1875
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.6077 - loss: 1.3000 - val_accuracy: 0.7000 - val_loss: 1.1267
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6092 - loss: 1.2839 - val_accuracy: 0.7000 - val_loss: 1.1021
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.6410 - loss: 1.2272 - val_accuracy: 0.7175 - val_loss: 1.0644
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6152 - loss: 1.2189 - val_accuracy: 0.7175 - val_loss: 1.0844
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6215 - loss: 1.2288 - val_accuracy: 0.7050 - val_loss: 1.0384
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6336 - loss: 1.1767 - val_accuracy: 0.7075 - val_loss: 1.0553
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6218 - loss: 1.1807 - val_accuracy: 0.7100 - val_loss: 1.0055
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6449 - loss: 1.1425 - val_accuracy: 0.7100 - val_loss: 1.0076
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6406 - loss: 1.1318 - val_accuracy: 0.7075 - val_loss: 0.9912
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6358 - loss: 1.1239 - val_accuracy: 0.6675 - val_loss: 1.0647
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6194 - loss: 1.1209 - val_accuracy: 0.6750 - val_loss: 1.0480
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6572 - loss: 1.0809 - val_accuracy: 0.7175 - val_loss: 0.9654
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6498 - loss: 1.0866 - val_accuracy: 0.7075 - val_loss: 0.9536
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.7159 - loss: 1.0469
# InceptionV3 Test Accuracy: 0.6950
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 549ms/step
#
# InceptionV3 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.49      0.42      0.45        50
# Bacterial Canker       0.70      0.88      0.78        50
#   Cutting Weevil       0.98      1.00      0.99        50
#         Die Back       0.90      0.90      0.90        50
#       Gall Midge       0.51      0.38      0.44        50
#          Healthy       0.84      0.72      0.77        50
#   Powdery Mildew       0.51      0.82      0.63        50
#      Sooty Mould       0.67      0.44      0.53        50
#
#         accuracy                           0.69       400
#        macro avg       0.70      0.70      0.69       400
#     weighted avg       0.70      0.69      0.69       400
# ==================================================
# Training EfficientNetB0
# ==================================================
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,411,435 (16.83 MB)
#  Trainable params: 361,864 (1.38 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 44s 186ms/step - accuracy: 0.5870 - loss: 8.8744 - val_accuracy: 0.9625 - val_loss: 4.6161
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9329 - loss: 4.1986 - val_accuracy: 0.9725 - val_loss: 2.8219
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9632 - loss: 2.6475 - val_accuracy: 0.9900 - val_loss: 1.9151
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9742 - loss: 1.8403 - val_accuracy: 0.9950 - val_loss: 1.3797
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9730 - loss: 1.3772 - val_accuracy: 0.9925 - val_loss: 1.0500
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9798 - loss: 1.0422 - val_accuracy: 0.9925 - val_loss: 0.8137
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9797 - loss: 0.8282 - val_accuracy: 0.9925 - val_loss: 0.6561
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9832 - loss: 0.6834 - val_accuracy: 0.9925 - val_loss: 0.5427
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9853 - loss: 0.5692 - val_accuracy: 0.9900 - val_loss: 0.4640
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9873 - loss: 0.4900 - val_accuracy: 0.9950 - val_loss: 0.4065
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9901 - loss: 0.4296 - val_accuracy: 0.9925 - val_loss: 0.3561
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9872 - loss: 0.3925 - val_accuracy: 0.9950 - val_loss: 0.3275
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9876 - loss: 0.3562 - val_accuracy: 0.9950 - val_loss: 0.3101
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9872 - loss: 0.3447 - val_accuracy: 0.9975 - val_loss: 0.2884
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9874 - loss: 0.3280 - val_accuracy: 0.9950 - val_loss: 0.2737
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9911 - loss: 0.3066 - val_accuracy: 0.9975 - val_loss: 0.2656
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9920 - loss: 0.2863 - val_accuracy: 0.9975 - val_loss: 0.2569
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9931 - loss: 0.2841 - val_accuracy: 0.9950 - val_loss: 0.2461
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9891 - loss: 0.2722 - val_accuracy: 0.9950 - val_loss: 0.2432
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9851 - loss: 0.2737 - val_accuracy: 0.9975 - val_loss: 0.2281
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9891 - loss: 0.2592 - val_accuracy: 0.9925 - val_loss: 0.2327
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9889 - loss: 0.2605 - val_accuracy: 0.9950 - val_loss: 0.2197
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9922 - loss: 0.2506 - val_accuracy: 0.9925 - val_loss: 0.2176
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9877 - loss: 0.2490 - val_accuracy: 0.9950 - val_loss: 0.2158
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 1.0000 - loss: 0.2825
# EfficientNetB0 Test Accuracy: 1.0000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 634ms/step
#
# EfficientNetB0 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       1.00      1.00      1.00        50
# Bacterial Canker       1.00      1.00      1.00        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       1.00      1.00      1.00        50
#       Gall Midge       1.00      1.00      1.00        50
#          Healthy       1.00      1.00      1.00        50
#   Powdery Mildew       1.00      1.00      1.00        50
#      Sooty Mould       1.00      1.00      1.00        50
#
#         accuracy                           1.00       400
#        macro avg       1.00      1.00      1.00       400
#     weighted avg       1.00      1.00      1.00       400
# ==================================================
# Training NASNetMobile
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ nasnet_mobile (Functional)      │ (None, 7, 7, 1056)     │     4,269,716 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 1056)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       270,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,574,236 (17.45 MB)
#  Trainable params: 304,520 (1.16 MB)
#  Non-trainable params: 4,269,716 (16.29 MB)
# Epoch 1/100
# E0000 00:00:1761383649.407536      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761383649.569531      99 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1710 - loss: 14.8774
# E0000 00:00:1761383680.177281      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761383680.329279      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 71s 316ms/step - accuracy: 0.1713 - loss: 14.8299 - val_accuracy: 0.2950 - val_loss: 4.6703
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.2832 - loss: 5.2686 - val_accuracy: 0.4225 - val_loss: 4.1492
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.3200 - loss: 4.3918 - val_accuracy: 0.4950 - val_loss: 3.8227
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - accuracy: 0.3835 - loss: 3.9838 - val_accuracy: 0.5350 - val_loss: 3.5858
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.4315 - loss: 3.7374 - val_accuracy: 0.5250 - val_loss: 3.4023
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4551 - loss: 3.5574 - val_accuracy: 0.5575 - val_loss: 3.2213
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4905 - loss: 3.3346 - val_accuracy: 0.5750 - val_loss: 3.0791
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.4836 - loss: 3.2493 - val_accuracy: 0.5700 - val_loss: 2.9523
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.4996 - loss: 3.1179 - val_accuracy: 0.5950 - val_loss: 2.8261
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5471 - loss: 2.9654 - val_accuracy: 0.5625 - val_loss: 2.7412
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - accuracy: 0.5548 - loss: 2.8337 - val_accuracy: 0.6100 - val_loss: 2.6064
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.5894 - loss: 2.6918 - val_accuracy: 0.5950 - val_loss: 2.5240
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.5598 - loss: 2.6216 - val_accuracy: 0.6075 - val_loss: 2.4148
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.5989 - loss: 2.5027 - val_accuracy: 0.6250 - val_loss: 2.3383
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.6121 - loss: 2.4101 - val_accuracy: 0.6250 - val_loss: 2.2353
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.6148 - loss: 2.3240 - val_accuracy: 0.6350 - val_loss: 2.1410
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - accuracy: 0.6262 - loss: 2.2353 - val_accuracy: 0.6450 - val_loss: 2.0692
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.6241 - loss: 2.1695 - val_accuracy: 0.6500 - val_loss: 1.9731
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6172 - loss: 2.1092 - val_accuracy: 0.6500 - val_loss: 1.9148
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.6408 - loss: 1.9799 - val_accuracy: 0.6675 - val_loss: 1.8588
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.6605 - loss: 1.9214 - val_accuracy: 0.6575 - val_loss: 1.7920
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.6672 - loss: 1.8487 - val_accuracy: 0.6775 - val_loss: 1.7011
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6678 - loss: 1.7831 - val_accuracy: 0.6550 - val_loss: 1.6545
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6578 - loss: 1.7141 - val_accuracy: 0.6775 - val_loss: 1.6155
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - accuracy: 0.6744 - loss: 1.6610 - val_accuracy: 0.6825 - val_loss: 1.5208
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.6748 - loss: 1.6281 - val_accuracy: 0.6900 - val_loss: 1.4929
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.6790 - loss: 1.5672 - val_accuracy: 0.6850 - val_loss: 1.4371
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - accuracy: 0.6761 - loss: 1.5402 - val_accuracy: 0.6925 - val_loss: 1.3771
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.6797 - loss: 1.4776 - val_accuracy: 0.7025 - val_loss: 1.3336
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6758 - loss: 1.4157 - val_accuracy: 0.6925 - val_loss: 1.3051
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6984 - loss: 1.3586 - val_accuracy: 0.6850 - val_loss: 1.2697
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.7062 - loss: 1.3188 - val_accuracy: 0.7000 - val_loss: 1.2393
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.7006 - loss: 1.2702 - val_accuracy: 0.7150 - val_loss: 1.1954
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.7148 - loss: 1.2492 - val_accuracy: 0.7250 - val_loss: 1.1751
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.7022 - loss: 1.2233 - val_accuracy: 0.7150 - val_loss: 1.1514
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.7183 - loss: 1.1958 - val_accuracy: 0.7000 - val_loss: 1.1542
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - accuracy: 0.7119 - loss: 1.1682 - val_accuracy: 0.7075 - val_loss: 1.1145
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.7093 - loss: 1.1924 - val_accuracy: 0.7200 - val_loss: 1.1036
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7016 - loss: 1.1416 - val_accuracy: 0.7200 - val_loss: 1.0736
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.7262 - loss: 1.1027 - val_accuracy: 0.7075 - val_loss: 1.0678
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.7219 - loss: 1.1019 - val_accuracy: 0.7225 - val_loss: 1.0461
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.7248 - loss: 1.0843 - val_accuracy: 0.7125 - val_loss: 1.0170
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.7204 - loss: 1.0553 - val_accuracy: 0.7475 - val_loss: 0.9912
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.7282 - loss: 1.0413 - val_accuracy: 0.7225 - val_loss: 1.0229
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.7236 - loss: 1.0381 - val_accuracy: 0.7350 - val_loss: 0.9887
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7428 - loss: 1.0068 - val_accuracy: 0.7050 - val_loss: 1.0081
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.7230 - loss: 1.0288 - val_accuracy: 0.7275 - val_loss: 0.9794
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.7561 - loss: 0.9797 - val_accuracy: 0.7325 - val_loss: 0.9897
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.7382 - loss: 1.0101 - val_accuracy: 0.7275 - val_loss: 0.9470
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7303 - loss: 0.9919 - val_accuracy: 0.7375 - val_loss: 0.9536
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7400 - loss: 0.9841 - val_accuracy: 0.7250 - val_loss: 0.9626
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.7416 - loss: 0.9512 - val_accuracy: 0.7350 - val_loss: 0.9549
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.7306 - loss: 0.9832 - val_accuracy: 0.7150 - val_loss: 0.9721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7558 - loss: 0.9650
# NASNetMobile Test Accuracy: 0.7450
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step
#
# NASNetMobile Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.62      0.76      0.68        50
# Bacterial Canker       0.90      0.86      0.88        50
#   Cutting Weevil       0.98      0.96      0.97        50
#         Die Back       0.96      0.92      0.94        50
#       Gall Midge       0.69      0.54      0.61        50
#          Healthy       0.84      0.76      0.80        50
#   Powdery Mildew       0.64      0.56      0.60        50
#      Sooty Mould       0.45      0.60      0.52        50
#
#         accuracy                           0.74       400
#        macro avg       0.76      0.74      0.75       400
#     weighted avg       0.76      0.74      0.75       400
