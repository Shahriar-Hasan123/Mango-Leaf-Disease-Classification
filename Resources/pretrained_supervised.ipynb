# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Conv2D, Dropout, Rescaling, Input
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Configuration
data_path = "/kaggle/input/mango-leaf-disease-dataset"
img_size = (224, 224)
batch_size = 32
mode = "rgb"
epochs = 100
SEED = 42

# Create dataframes
def df_maker(path):
    file_paths = []
    labels = []

    folds = os.listdir(path)
    for fold in folds:
        fold_path = os.path.join(path, fold)
        file_list = os.listdir(fold_path)
        for file in file_list:
            file_path = os.path.join(fold_path, file)
            file_paths.append(file_path)
            labels.append(fold)

    file_series = pd.Series(file_paths, name="file_paths")
    label_series = pd.Series(labels, name="labels")

    df = pd.concat([file_series, label_series], axis=1)
    return df

# Create dataframe
df = df_maker(data_path)

# Split data
train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=SEED, stratify=df["labels"])
test_df, val_df = train_test_split(test_df, train_size=0.5, shuffle=True, random_state=SEED, stratify=test_df["labels"])

# Data generators
train_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()
val_datagen = ImageDataGenerator()

train_data = train_datagen.flow_from_dataframe(
    train_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
)
test_data = test_datagen.flow_from_dataframe(
    test_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=False,
)
val_data = val_datagen.flow_from_dataframe(
    val_df,
    x_col="file_paths",
    y_col="labels",
    target_size=img_size,
    color_mode=mode,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
)

# Get class names
class_names = list(train_data.class_indices.keys())
num_classes = len(class_names)

# Model configurations
MODEL_CONFIG = {
    'VGG16': {
        'model_class': tf.keras.applications.VGG16,
        'preprocess_input': tf.keras.applications.vgg16.preprocess_input,
        'layers_to_unfreeze': 4,
        'input_shape': (224, 224, 3)
    },
    'MobileNetV2': {
        'model_class': tf.keras.applications.MobileNetV2,
        'preprocess_input': tf.keras.applications.mobilenet_v2.preprocess_input,
        'layers_to_unfreeze': 20,
        'input_shape': (224, 224, 3)
    },
    'DenseNet121': {
        'model_class': tf.keras.applications.DenseNet121,
        'preprocess_input': tf.keras.applications.densenet.preprocess_input,
        'layers_to_unfreeze': 15,
        'input_shape': (224, 224, 3)
    },
    'ResNet101': {
        'model_class': tf.keras.applications.ResNet101,
        'preprocess_input': tf.keras.applications.resnet.preprocess_input,
        'layers_to_unfreeze': 30,
        'input_shape': (224, 224, 3)
    }
}

# Function to create model
def create_model(model_name):
    config = MODEL_CONFIG[model_name]
    
    # Create base model
    base_model = config['model_class'](
        weights='imagenet',
        include_top=False,
        input_shape=config['input_shape']
    )
    
    # Freeze base model
    base_model.trainable = False
    
    # Create model
    model = Sequential([
        Input(shape=config['input_shape']),
        base_model,
        GlobalAveragePooling2D(),
        Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.5),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    
    # Compile model
    model.compile(
        optimizer=Adamax(learning_rate=1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model, base_model

# Function to train model
def train_model(model, model_name, epochs=25):
    # Create callbacks
    checkpoint = ModelCheckpoint(
        f'{model_name}_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max'
    )
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        mode='max'
    )
    
    # Train model
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=epochs,
        callbacks=[checkpoint, early_stopping]
    )
    
    return history

# Function to evaluate model
def evaluate_model(model, model_name):
    # Evaluate on test data
    test_loss, test_acc = model.evaluate(test_data)
    print(f"{model_name} Test Accuracy: {test_acc:.4f}")
    
    # Make predictions
    predictions = model.predict(test_data)
    y_pred = np.argmax(predictions, axis=1)
    y_true = test_data.classes
    
    # Print classification report
    print(f"\n{model_name} Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))
    
    # Plot confusion matrix
    plt.figure(figsize=(12, 9))
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap=plt.cm.Blues)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.title(f"{model_name} Confusion Matrix")
    plt.show()
    
    return test_acc, y_pred, y_true

# Function to plot training history
def plot_history(history, model_name):
    # Create dataframe from history
    vals = pd.DataFrame(history.history)
    vals = vals.rename(columns={
        "loss": "Train Loss",
        "val_loss": "Validation Loss",
        "accuracy": "Train Accuracy",
        "val_accuracy": "Validation Accuracy"
    })
    
    # Plot accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(vals["Train Accuracy"], label="Training Accuracy")
    plt.plot(vals["Validation Accuracy"], label="Validation Accuracy")
    plt.title(f"{model_name} Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(vals["Train Loss"], label="Training Loss")
    plt.plot(vals["Validation Loss"], label="Validation Loss")
    plt.title(f"{model_name} Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    
    plt.tight_layout()
    plt.show()



# Train and evaluate models
results = {}
models_to_train = ['VGG16', 'MobileNetV2', 'DenseNet121', 'ResNet101']

for model_name in models_to_train:
    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")
    
    # Create model
    model, base_model = create_model(model_name)
    model.summary()
    
    # Train model
    history = train_model(model, model_name, epochs)
    
    # Plot training history
    plot_history(history, model_name)
    
    # Evaluate model
    test_acc, y_pred, y_true = evaluate_model(model, model_name)
# Out:
# 2025-10-24 21:53:43.583389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761342823.809828      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761342823.874401      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 3200 validated image filenames belonging to 8 classes.
# Found 400 validated image filenames belonging to 8 classes.
# Found 400 validated image filenames belonging to 8 classes.
#
# ==================================================
# Training VGG16
# ==================================================
# I0000 00:00:1761342844.654303      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1761342844.655031      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,879,944 (56.76 MB)
#  Trainable params: 165,256 (645.53 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761342849.841967      99 service.cc:148] XLA service 0x7f90f800e700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761342849.843251      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761342849.843273      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1761342850.323006      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 26:03 16s/step - accuracy: 0.2188 - loss: 16.8206
# I0000 00:00:1761342862.937671      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 46s 307ms/step - accuracy: 0.3803 - loss: 10.4732 - val_accuracy: 0.9000 - val_loss: 6.9580
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 203ms/step - accuracy: 0.7481 - loss: 7.0994 - val_accuracy: 0.9425 - val_loss: 6.0828
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 211ms/step - accuracy: 0.8280 - loss: 6.1882 - val_accuracy: 0.9600 - val_loss: 5.4350
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.8553 - loss: 5.5574 - val_accuracy: 0.9550 - val_loss: 4.9304
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 244ms/step - accuracy: 0.8977 - loss: 4.9739 - val_accuracy: 0.9750 - val_loss: 4.4599
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 255ms/step - accuracy: 0.9179 - loss: 4.4976 - val_accuracy: 0.9725 - val_loss: 4.0522
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9109 - loss: 4.1098 - val_accuracy: 0.9750 - val_loss: 3.6909
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9396 - loss: 3.7009 - val_accuracy: 0.9750 - val_loss: 3.3482
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - accuracy: 0.9443 - loss: 3.3508 - val_accuracy: 0.9775 - val_loss: 3.0357
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - accuracy: 0.9444 - loss: 3.0471 - val_accuracy: 0.9825 - val_loss: 2.7509
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - accuracy: 0.9492 - loss: 2.7690 - val_accuracy: 0.9875 - val_loss: 2.4895
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 242ms/step - accuracy: 0.9606 - loss: 2.4950 - val_accuracy: 0.9775 - val_loss: 2.2580
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - accuracy: 0.9598 - loss: 2.2562 - val_accuracy: 0.9825 - val_loss: 2.0362
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 245ms/step - accuracy: 0.9697 - loss: 2.0274 - val_accuracy: 0.9825 - val_loss: 1.8302
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - accuracy: 0.9654 - loss: 1.8454 - val_accuracy: 0.9825 - val_loss: 1.6470
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 245ms/step - accuracy: 0.9772 - loss: 1.6351 - val_accuracy: 0.9825 - val_loss: 1.4746
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - accuracy: 0.9717 - loss: 1.4871 - val_accuracy: 0.9825 - val_loss: 1.3278
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - accuracy: 0.9767 - loss: 1.3262 - val_accuracy: 0.9875 - val_loss: 1.1869
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 246ms/step - accuracy: 0.9781 - loss: 1.1850 - val_accuracy: 0.9850 - val_loss: 1.0629
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 245ms/step - accuracy: 0.9823 - loss: 1.0603 - val_accuracy: 0.9800 - val_loss: 0.9606
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - accuracy: 0.9828 - loss: 0.9576 - val_accuracy: 0.9800 - val_loss: 0.8662
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.9756 - loss: 2.4927
# VGG16 Test Accuracy: 0.9875
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step
#
# VGG16 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.94      1.00      0.97        50
# Bacterial Canker       1.00      1.00      1.00        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       1.00      1.00      1.00        50
#       Gall Midge       0.98      0.96      0.97        50
#          Healthy       1.00      1.00      1.00        50
#   Powdery Mildew       1.00      0.98      0.99        50
#      Sooty Mould       0.98      0.96      0.97        50
#
#         accuracy                           0.99       400
#        macro avg       0.99      0.99      0.99       400
#     weighted avg       0.99      0.99      0.99       400
# ==================================================
# Training MobileNetV2
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,619,848 (9.99 MB)
#  Trainable params: 361,864 (1.38 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - accuracy: 0.3631 - loss: 9.0235 - val_accuracy: 0.7700 - val_loss: 5.1862
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.6710 - loss: 4.9488 - val_accuracy: 0.8300 - val_loss: 3.7930
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.7241 - loss: 3.7801 - val_accuracy: 0.8400 - val_loss: 3.0416
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.8052 - loss: 3.0220 - val_accuracy: 0.8550 - val_loss: 2.5300
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.8216 - loss: 2.5244 - val_accuracy: 0.8700 - val_loss: 2.1412
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.8397 - loss: 2.1803 - val_accuracy: 0.8975 - val_loss: 1.8364
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8474 - loss: 1.8918 - val_accuracy: 0.8750 - val_loss: 1.6518
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.8641 - loss: 1.6676 - val_accuracy: 0.8825 - val_loss: 1.4429
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.8682 - loss: 1.4732 - val_accuracy: 0.8875 - val_loss: 1.3006
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.8733 - loss: 1.3452 - val_accuracy: 0.8800 - val_loss: 1.1995
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.8863 - loss: 1.1959 - val_accuracy: 0.9025 - val_loss: 1.0893
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8848 - loss: 1.1076 - val_accuracy: 0.9000 - val_loss: 0.9846
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.8821 - loss: 1.0247 - val_accuracy: 0.9075 - val_loss: 0.9022
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.8916 - loss: 0.9461 - val_accuracy: 0.8950 - val_loss: 0.8765
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.8962 - loss: 0.8864 - val_accuracy: 0.9025 - val_loss: 0.8149
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9084 - loss: 0.8242 - val_accuracy: 0.9075 - val_loss: 0.7650
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9007 - loss: 0.7930 - val_accuracy: 0.8900 - val_loss: 0.7567
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9099 - loss: 0.7376 - val_accuracy: 0.9025 - val_loss: 0.7082
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9198 - loss: 0.7047 - val_accuracy: 0.9125 - val_loss: 0.6683
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9131 - loss: 0.6933 - val_accuracy: 0.9125 - val_loss: 0.6336
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9197 - loss: 0.6475 - val_accuracy: 0.8975 - val_loss: 0.6495
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9083 - loss: 0.6505 - val_accuracy: 0.8975 - val_loss: 0.6201
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9272 - loss: 0.6086 - val_accuracy: 0.8950 - val_loss: 0.6349
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9061 - loss: 0.6251 - val_accuracy: 0.8925 - val_loss: 0.6164
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9161 - loss: 0.5876 - val_accuracy: 0.9075 - val_loss: 0.5733
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9262 - loss: 0.5756 - val_accuracy: 0.9150 - val_loss: 0.5548
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9254 - loss: 0.5620 - val_accuracy: 0.9175 - val_loss: 0.5634
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9270 - loss: 0.5540 - val_accuracy: 0.9125 - val_loss: 0.5467
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.9177 - loss: 0.5565 - val_accuracy: 0.9100 - val_loss: 0.5445
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9250 - loss: 0.5383 - val_accuracy: 0.9150 - val_loss: 0.5301
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9425 - loss: 0.5069 - val_accuracy: 0.9150 - val_loss: 0.5243
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9150 - loss: 0.5320 - val_accuracy: 0.9125 - val_loss: 0.5231
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9184 - loss: 0.5239 - val_accuracy: 0.9075 - val_loss: 0.5270
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9399 - loss: 0.4922 - val_accuracy: 0.9025 - val_loss: 0.5359
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9222 - loss: 0.4997 - val_accuracy: 0.9075 - val_loss: 0.5297
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9287 - loss: 0.5061 - val_accuracy: 0.9150 - val_loss: 0.4926
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9295 - loss: 0.4807 - val_accuracy: 0.8950 - val_loss: 0.5477
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9166 - loss: 0.5546
# MobileNetV2 Test Accuracy: 0.9125
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step
#
# MobileNetV2 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.84      0.84      0.84        50
# Bacterial Canker       0.82      1.00      0.90        50
#   Cutting Weevil       0.98      1.00      0.99        50
#         Die Back       0.98      0.90      0.94        50
#       Gall Midge       0.86      0.88      0.87        50
#          Healthy       1.00      0.96      0.98        50
#   Powdery Mildew       0.94      0.92      0.93        50
#      Sooty Mould       0.91      0.80      0.85        50
#
#         accuracy                           0.91       400
#        macro avg       0.92      0.91      0.91       400
#     weighted avg       0.92      0.91      0.91       400
# ==================================================
# Training DenseNet121
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,333,832 (27.98 MB)
#  Trainable params: 296,328 (1.13 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 65s 327ms/step - accuracy: 0.2600 - loss: 12.7094 - val_accuracy: 0.6325 - val_loss: 5.0344
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 12s 115ms/step - accuracy: 0.4976 - loss: 5.1127 - val_accuracy: 0.7075 - val_loss: 4.2880
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.5717 - loss: 4.5395 - val_accuracy: 0.7250 - val_loss: 3.9221
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 105ms/step - accuracy: 0.6185 - loss: 4.1174 - val_accuracy: 0.7575 - val_loss: 3.5930
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.6622 - loss: 3.8183 - val_accuracy: 0.8125 - val_loss: 3.3142
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.7044 - loss: 3.5157 - val_accuracy: 0.8500 - val_loss: 3.0668
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - accuracy: 0.7342 - loss: 3.2884 - val_accuracy: 0.8550 - val_loss: 2.8830
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7454 - loss: 3.1041 - val_accuracy: 0.8575 - val_loss: 2.7247
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 155ms/step - accuracy: 0.7781 - loss: 2.8766 - val_accuracy: 0.8825 - val_loss: 2.5467
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 147ms/step - accuracy: 0.7920 - loss: 2.7171 - val_accuracy: 0.8700 - val_loss: 2.4326
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.7800 - loss: 2.6457 - val_accuracy: 0.8875 - val_loss: 2.2682
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 108ms/step - accuracy: 0.8034 - loss: 2.4522 - val_accuracy: 0.8950 - val_loss: 2.1501
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.8077 - loss: 2.3307 - val_accuracy: 0.8975 - val_loss: 2.0343
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.8415 - loss: 2.1548 - val_accuracy: 0.9250 - val_loss: 1.9204
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.8425 - loss: 2.0609 - val_accuracy: 0.9100 - val_loss: 1.7944
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.8383 - loss: 1.9801 - val_accuracy: 0.9250 - val_loss: 1.6848
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8426 - loss: 1.8720 - val_accuracy: 0.9175 - val_loss: 1.6067
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8476 - loss: 1.7711 - val_accuracy: 0.9225 - val_loss: 1.5195
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.8497 - loss: 1.6700 - val_accuracy: 0.9325 - val_loss: 1.4388
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.8589 - loss: 1.5933 - val_accuracy: 0.9250 - val_loss: 1.3513
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8642 - loss: 1.4990 - val_accuracy: 0.9225 - val_loss: 1.3093
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.8879 - loss: 1.3914 - val_accuracy: 0.9225 - val_loss: 1.2172
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.8742 - loss: 1.3390 - val_accuracy: 0.9225 - val_loss: 1.1499
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.8748 - loss: 1.2897 - val_accuracy: 0.9375 - val_loss: 1.0771
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8958 - loss: 1.1828 - val_accuracy: 0.9375 - val_loss: 1.0439
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8911 - loss: 1.1649 - val_accuracy: 0.9375 - val_loss: 0.9887
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.8980 - loss: 1.0998 - val_accuracy: 0.9425 - val_loss: 0.9129
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8958 - loss: 1.0483 - val_accuracy: 0.9425 - val_loss: 0.8991
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8964 - loss: 1.0190 - val_accuracy: 0.9400 - val_loss: 0.8526
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.8905 - loss: 0.9658 - val_accuracy: 0.9525 - val_loss: 0.7840
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9056 - loss: 0.9224 - val_accuracy: 0.9475 - val_loss: 0.7473
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9014 - loss: 0.8864 - val_accuracy: 0.9450 - val_loss: 0.7307
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.8962 - loss: 0.8524 - val_accuracy: 0.9400 - val_loss: 0.6999
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9069 - loss: 0.8295 - val_accuracy: 0.9400 - val_loss: 0.6831
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9095 - loss: 0.7886 - val_accuracy: 0.9400 - val_loss: 0.6734
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.9158 - loss: 0.7323 - val_accuracy: 0.9525 - val_loss: 0.6278
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 105ms/step - accuracy: 0.9160 - loss: 0.7366 - val_accuracy: 0.9550 - val_loss: 0.5952
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.9162 - loss: 0.6968 - val_accuracy: 0.9600 - val_loss: 0.5806
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9049 - loss: 0.6951 - val_accuracy: 0.9525 - val_loss: 0.5548
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9092 - loss: 0.6691 - val_accuracy: 0.9600 - val_loss: 0.5363
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9139 - loss: 0.6617 - val_accuracy: 0.9575 - val_loss: 0.5214
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.9203 - loss: 0.6208 - val_accuracy: 0.9650 - val_loss: 0.5037
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9222 - loss: 0.5949 - val_accuracy: 0.9575 - val_loss: 0.5060
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.9251 - loss: 0.5854 - val_accuracy: 0.9475 - val_loss: 0.5071
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9228 - loss: 0.5929 - val_accuracy: 0.9500 - val_loss: 0.4801
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.9222 - loss: 0.5630 - val_accuracy: 0.9675 - val_loss: 0.4643
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9298 - loss: 0.5474 - val_accuracy: 0.9450 - val_loss: 0.4948
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9234 - loss: 0.5563 - val_accuracy: 0.9400 - val_loss: 0.4663
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9298 - loss: 0.5333 - val_accuracy: 0.9475 - val_loss: 0.4573
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - accuracy: 0.9175 - loss: 0.5515 - val_accuracy: 0.9500 - val_loss: 0.4353
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9362 - loss: 0.5098 - val_accuracy: 0.9450 - val_loss: 0.4277
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.9354 - loss: 0.4995 - val_accuracy: 0.9500 - val_loss: 0.4265
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9257 - loss: 0.5129 - val_accuracy: 0.9675 - val_loss: 0.3992
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9239 - loss: 0.5023 - val_accuracy: 0.9675 - val_loss: 0.4008
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - accuracy: 0.9308 - loss: 0.4936 - val_accuracy: 0.9575 - val_loss: 0.4003
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 95ms/step - accuracy: 0.9339 - loss: 0.4723 - val_accuracy: 0.9600 - val_loss: 0.4162
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.9509 - loss: 0.4993
# DenseNet121 Test Accuracy: 0.9525
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step
#
# DenseNet121 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.98      0.94      0.96        50
# Bacterial Canker       0.96      0.98      0.97        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       0.94      1.00      0.97        50
#       Gall Midge       0.98      0.88      0.93        50
#          Healthy       0.96      1.00      0.98        50
#   Powdery Mildew       0.90      0.94      0.92        50
#      Sooty Mould       0.90      0.88      0.89        50
#
#         accuracy                           0.95       400
#        macro avg       0.95      0.95      0.95       400
#     weighted avg       0.95      0.95      0.95       400
# ==================================================
# Training ResNet101
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet101 (Functional)          │ (None, 7, 7, 2048)     │    42,658,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │         1,032 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,216,648 (164.86 MB)
#  Trainable params: 558,472 (2.13 MB)
#  Non-trainable params: 42,658,176 (162.73 MB)
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 64s 363ms/step - accuracy: 0.5657 - loss: 9.5379 - val_accuracy: 0.9650 - val_loss: 5.7553
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 225ms/step - accuracy: 0.8985 - loss: 5.4770 - val_accuracy: 0.9700 - val_loss: 4.2240
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.9438 - loss: 4.0583 - val_accuracy: 0.9900 - val_loss: 3.2712
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - accuracy: 0.9576 - loss: 3.1805 - val_accuracy: 0.9975 - val_loss: 2.6008
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 250ms/step - accuracy: 0.9659 - loss: 2.5533 - val_accuracy: 0.9975 - val_loss: 2.1095
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.9765 - loss: 2.0778 - val_accuracy: 0.9950 - val_loss: 1.7224
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9766 - loss: 1.7158 - val_accuracy: 0.9925 - val_loss: 1.4275
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 240ms/step - accuracy: 0.9841 - loss: 1.4007 - val_accuracy: 0.9925 - val_loss: 1.1819
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 236ms/step - accuracy: 0.9809 - loss: 1.1764 - val_accuracy: 0.9975 - val_loss: 0.9832
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9815 - loss: 0.9893 - val_accuracy: 0.9975 - val_loss: 0.8312
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - accuracy: 0.9839 - loss: 0.8421 - val_accuracy: 1.0000 - val_loss: 0.6961
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9849 - loss: 0.7210 - val_accuracy: 0.9950 - val_loss: 0.5956
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - accuracy: 0.9853 - loss: 0.6098 - val_accuracy: 0.9875 - val_loss: 0.5251
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9902 - loss: 0.5305 - val_accuracy: 1.0000 - val_loss: 0.4421
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9918 - loss: 0.4526 - val_accuracy: 0.9950 - val_loss: 0.3883
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9909 - loss: 0.4062 - val_accuracy: 1.0000 - val_loss: 0.3492
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 237ms/step - accuracy: 0.9914 - loss: 0.3610 - val_accuracy: 0.9975 - val_loss: 0.3104
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - accuracy: 0.9896 - loss: 0.3274 - val_accuracy: 0.9975 - val_loss: 0.2801
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 237ms/step - accuracy: 0.9885 - loss: 0.3009 - val_accuracy: 0.9950 - val_loss: 0.2575
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 236ms/step - accuracy: 0.9918 - loss: 0.2703 - val_accuracy: 0.9925 - val_loss: 0.2437
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9922 - loss: 0.2560 - val_accuracy: 0.9975 - val_loss: 0.2221
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9913 - loss: 0.7102
# ResNet101 Test Accuracy: 0.9900
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 934ms/step
#
# ResNet101 Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.98      0.98      0.98        50
# Bacterial Canker       0.98      1.00      0.99        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       1.00      0.98      0.99        50
#       Gall Midge       0.98      0.96      0.97        50
#          Healthy       1.00      1.00      1.00        50
#   Powdery Mildew       1.00      1.00      1.00        50
#      Sooty Mould       0.98      1.00      0.99        50
#
#         accuracy                           0.99       400
#        macro avg       0.99      0.99      0.99       400
#     weighted avg       0.99      0.99      0.99       400
