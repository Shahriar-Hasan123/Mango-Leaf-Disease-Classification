# %%
# -*- coding: utf-8 -*-
"""Semi-Supervised Mango Leaf Classification with Pseudo-Labeling"""

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download aryashah2k/mango-leaf-disease-dataset

import os
import numpy as np
import pandas as pd
import random
import shutil
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.utils import image_dataset_from_directory, load_img, img_to_array
import matplotlib.pyplot as plt

"""# Step 1: Split Data into Train (80%), Validation (10%), Test (10%)"""

import kagglehub

# Paths
source_dir = kagglehub.dataset_download("aryashah2k/mango-leaf-disease-dataset")
base_dir = '/content/semi_supervised_data/'

# Create main directories
for split in ['train', 'validation', 'test']:
    os.makedirs(os.path.join(base_dir, split), exist_ok=True)

classes = [c for c in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, c))]

# Create class subdirectories
for cls in classes:
    for split in ['train', 'validation', 'test']:
        os.makedirs(os.path.join(base_dir, split, cls), exist_ok=True)

# Split data: 80% train, 10% validation, 10% test
def split_data():
    for cls in classes:
        class_dir = os.path.join(source_dir, cls)
        if os.path.isdir(class_dir):
            images = [img for img in os.listdir(class_dir) if img.endswith(('.jpg', '.jpeg', '.png'))]
            random.shuffle(images)

            total = len(images)
            train_size = int(0.8 * total)
            val_size = int(0.1 * total)

            train_images = images[:train_size]
            val_images = images[train_size:train_size + val_size]
            test_images = images[train_size + val_size:]

            # Copy images
            for image in train_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'train', cls, image))
            for image in val_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'validation', cls, image))
            for image in test_images:
                shutil.copy2(os.path.join(class_dir, image),
                           os.path.join(base_dir, 'test', cls, image))

split_data()
print("✅ Data split into 80% train, 10% validation, 10% test")

"""# Step 2: Split Train Data into Labeled (25%) and Unlabeled (75%)"""

labeled_dir = '/content/semi_supervised_data/labeled/'
unlabeled_dir = '/content/semi_supervised_data/unlabeled/'

# Create directories
for cls in classes:
    os.makedirs(os.path.join(labeled_dir, cls), exist_ok=True)
    os.makedirs(os.path.join(unlabeled_dir, cls), exist_ok=True)

def split_labeled_unlabeled():
    train_dir = os.path.join(base_dir, 'train')

    for cls in classes:
        class_dir = os.path.join(train_dir, cls)
        images = [img for img in os.listdir(class_dir) if img.endswith(('.jpg', '.jpeg', '.png'))]
        random.shuffle(images)

        labeled_size = int(0.25 * len(images))
        labeled_images = images[:labeled_size]
        unlabeled_images = images[labeled_size:]

        # Copy labeled images
        for image in labeled_images:
            shutil.copy2(os.path.join(class_dir, image),
                       os.path.join(labeled_dir, cls, image))

        # Copy unlabeled images
        for image in unlabeled_images:
            shutil.copy2(os.path.join(class_dir, image),
                       os.path.join(unlabeled_dir, cls, image))

split_labeled_unlabeled()
print("✅ Train data split into 25% labeled and 75% unlabeled")

# Print dataset statistics
print("\n📊 Dataset Statistics:")
for split_name, split_path in [('Labeled', labeled_dir),
                                ('Unlabeled', unlabeled_dir),
                                ('Validation', os.path.join(base_dir, 'validation')),
                                ('Test', os.path.join(base_dir, 'test'))]:
    total = sum([len(os.listdir(os.path.join(split_path, cls))) for cls in classes])
    print(f"{split_name}: {total} images")

"""# Step 3: Load Datasets"""

img_size = (224, 224)
batch_size = 32

# Load labeled dataset
labeled_dataset = image_dataset_from_directory(
    labeled_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=True
)

# Load validation dataset
val_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'validation'),
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=False
)

# Load test dataset
test_dataset = image_dataset_from_directory(
    os.path.join(base_dir, 'test'),
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=False
)

class_names = labeled_dataset.class_names
num_classes = len(class_names)
print(f"\n🏷️ Classes: {class_names}")

"""# Step 4: Preprocess Datasets"""

def preprocess_data(image, label):
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

labeled_dataset = labeled_dataset.map(preprocess_data)
val_dataset = val_dataset.map(preprocess_data)
test_dataset = test_dataset.map(preprocess_data)
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'
# Using Colab cache for faster access to the 'mango-leaf-disease-dataset' dataset.
# ✅ Data split into 80% train, 10% validation, 10% test
# ✅ Train data split into 25% labeled and 75% unlabeled
#
# 📊 Dataset Statistics:
# Labeled: 800 images
# Unlabeled: 2400 images
# Validation: 400 images
# Test: 400 images
# Found 800 files belonging to 8 classes.
# Found 400 files belonging to 8 classes.
# Found 400 files belonging to 8 classes.
#
# 🏷️ Classes: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']

# %%
"""# Step 5: Build Model"""
from keras import regularizers
from keras.layers import MaxPooling2D, Flatten, Dense, BatchNormalization, GlobalAveragePooling2D, Conv2D, Dropout, Rescaling, Input
from keras.models import Sequential
def build_model():
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze base model
    base_model.trainable = False

    # Create model
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.5),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.016)),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

model = build_model()

"""# Step 6: Train on Labeled Data (30 Epochs)"""

print("\n🚀 Phase 1: Training on Labeled Data (30 epochs)")

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

history_labeled = model.fit(
    labeled_dataset,
    validation_data=val_dataset,
    epochs=30,
    callbacks=[early_stop, reduce_lr]
)


# Evaluate on validation set
test_loss, test_acc = model.evaluate(test_dataset)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🚀 Phase 1: Training on Labeled Data (30 epochs)
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.2846 - loss: 10.1416 - val_accuracy: 0.8800 - val_loss: 6.1932 - learning_rate: 0.0010
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.7492 - loss: 5.7321 - val_accuracy: 0.9375 - val_loss: 4.0040 - learning_rate: 0.0010
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.8559 - loss: 3.8795 - val_accuracy: 0.9525 - val_loss: 2.9559 - learning_rate: 0.0010
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.8979 - loss: 2.9492 - val_accuracy: 0.9650 - val_loss: 2.3808 - learning_rate: 0.0010
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9283 - loss: 2.3697 - val_accuracy: 0.9775 - val_loss: 1.9443 - learning_rate: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9321 - loss: 1.9795 - val_accuracy: 0.9650 - val_loss: 1.6357 - learning_rate: 0.0010
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.9533 - loss: 1.6342 - val_accuracy: 0.9775 - val_loss: 1.3755 - learning_rate: 0.0010
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9649 - loss: 1.3909 - val_accuracy: 0.9700 - val_loss: 1.1886 - learning_rate: 0.0010
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.9658 - loss: 1.1849 - val_accuracy: 0.9650 - val_loss: 1.0528 - learning_rate: 0.0010
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9663 - loss: 1.0576 - val_accuracy: 0.9775 - val_loss: 0.9069 - learning_rate: 0.0010
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9718 - loss: 0.9178 - val_accuracy: 0.9775 - val_loss: 0.7970 - learning_rate: 0.0010
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9748 - loss: 0.8113 - val_accuracy: 0.9900 - val_loss: 0.7055 - learning_rate: 0.0010
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9714 - loss: 0.7330 - val_accuracy: 0.9750 - val_loss: 0.6472 - learning_rate: 0.0010
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.9714 - loss: 0.6620 - val_accuracy: 0.9825 - val_loss: 0.5824 - learning_rate: 0.0010
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.9798 - loss: 0.6064 - val_accuracy: 0.9850 - val_loss: 0.5294 - learning_rate: 0.0010
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.9813 - loss: 0.5577 - val_accuracy: 0.9800 - val_loss: 0.4961 - learning_rate: 0.0010
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9839 - loss: 0.4995 - val_accuracy: 0.9825 - val_loss: 0.4577 - learning_rate: 0.0010
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9796 - loss: 0.4699 - val_accuracy: 0.9875 - val_loss: 0.4195 - learning_rate: 0.0010
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9858 - loss: 0.4434 - val_accuracy: 0.9800 - val_loss: 0.4271 - learning_rate: 0.0010
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9882 - loss: 0.4184 - val_accuracy: 0.9875 - val_loss: 0.3797 - learning_rate: 0.0010
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9922 - loss: 0.3873 - val_accuracy: 0.9825 - val_loss: 0.3724 - learning_rate: 0.0010
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9725 - loss: 0.3812 - val_accuracy: 0.9900 - val_loss: 0.3539 - learning_rate: 0.0010
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9765 - loss: 0.3722 - val_accuracy: 0.9850 - val_loss: 0.3397 - learning_rate: 0.0010
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9833 - loss: 0.3598 - val_accuracy: 0.9700 - val_loss: 0.3474 - learning_rate: 0.0010
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9819 - loss: 0.3542 - val_accuracy: 0.9800 - val_loss: 0.3170 - learning_rate: 0.0010
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9951 - loss: 0.3162 - val_accuracy: 0.9750 - val_loss: 0.3174 - learning_rate: 0.0010
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9733 - loss: 0.3394 - val_accuracy: 0.9700 - val_loss: 0.3422 - learning_rate: 0.0010
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9803 - loss: 0.3440 - val_accuracy: 0.9775 - val_loss: 0.3528 - learning_rate: 0.0010
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9703 - loss: 0.3537 - val_accuracy: 0.9850 - val_loss: 0.3153 - learning_rate: 0.0010
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9846 - loss: 0.3263 - val_accuracy: 0.9850 - val_loss: 0.3011 - learning_rate: 0.0010
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9721 - loss: 0.3262
# ✅ After Labeled Training - Validation Accuracy: 97.25%

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_labeled.history["accuracy"], label="Training Accuracy for Labeled Data")
plt.plot(history_labeled.history["val_accuracy"], label="Validation Accuracy for Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_labeled.history["loss"], label="Training Loss for Labeled Data")
plt.plot(history_labeled.history["val_loss"], label="Validation Loss for Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# ✅ After Labeled Training - Validation Accuracy: 97.25%

# %%
"""# Step 7: Generate Pseudo-Labels for Unlabeled Data"""

print("\n🔮 Generating Pseudo-Labels for Unlabeled Data...")

# Create pseudo-labeled directory
pseudo_labeled_dir = '/content/semi_supervised_data/pseudo_labeled/'
for cls in classes:
    os.makedirs(os.path.join(pseudo_labeled_dir, cls), exist_ok=True)

# Generate pseudo-labels with confidence threshold
confidence_threshold = 0.7

def generate_pseudo_labels():
    pseudo_count = 0

    for cls in classes:
        class_path = os.path.join(unlabeled_dir, cls)
        images = [img for img in os.listdir(class_path) if img.endswith(('.jpg', '.jpeg', '.png'))]

        for img_name in images:
            img_path = os.path.join(class_path, img_name)

            # Load and preprocess image
            img = load_img(img_path, target_size=img_size)
            img_array = img_to_array(img) / 255.0
            img_array = np.expand_dims(img_array, axis=0)

            # Predict
            predictions = model.predict(img_array, verbose=0)
            confidence = np.max(predictions)
            predicted_class_idx = np.argmax(predictions)
            predicted_class = class_names[predicted_class_idx]

            # Only use high-confidence predictions
            if confidence >= confidence_threshold:
                dest_path = os.path.join(pseudo_labeled_dir, predicted_class, img_name)
                shutil.copy2(img_path, dest_path)
                pseudo_count += 1

    return pseudo_count

pseudo_count = generate_pseudo_labels()
print(f"✅ Generated {pseudo_count} pseudo-labels (confidence >= {confidence_threshold})")

"""# Step 8: Merge Labeled and Pseudo-Labeled Data"""

merged_dir = '/content/semi_supervised_data/merged/'
for cls in classes:
    os.makedirs(os.path.join(merged_dir, cls), exist_ok=True)

def merge_datasets():
    # Copy labeled data
    for cls in classes:
        labeled_path = os.path.join(labeled_dir, cls)
        images = os.listdir(labeled_path)
        for img in images:
            shutil.copy2(os.path.join(labeled_path, img),
                       os.path.join(merged_dir, cls, img))

    # Copy pseudo-labeled data
    for cls in classes:
        pseudo_path = os.path.join(pseudo_labeled_dir, cls)
        if os.path.exists(pseudo_path):
            images = os.listdir(pseudo_path)
            for img in images:
                shutil.copy2(os.path.join(pseudo_path, img),
                           os.path.join(merged_dir, cls, f"pseudo_{img}"))

merge_datasets()

# Load merged dataset
merged_dataset = image_dataset_from_directory(
    merged_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=True
)
merged_dataset = merged_dataset.map(preprocess_data)

merged_count = sum([len(os.listdir(os.path.join(merged_dir, cls))) for cls in classes])
print(f"✅ Merged dataset created with {merged_count} images")

"""# Step 9: Train on Merged Data (100 Epochs)"""

print("\n🚀 Phase 2: Training on Merged Data (100 epochs)")

# Rebuild model or continue with existing
# Option 1: Continue with same model
# Option 2: Rebuild model (uncomment below)
# model = build_model()

history_merged = model.fit(
    merged_dataset,
    validation_data=val_dataset,
    epochs=100,
    callbacks=[early_stop, reduce_lr]
)

"""# Step 10: Final Evaluation"""

test_loss, test_acc = model.evaluate(test_dataset)
print(f"\n🎯 Final Test Accuracy: {test_acc * 100:.2f}%")

"""# Step 11: Plot Training History"""

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history_merged.history["accuracy"], label="Training Accuracy for Unlabeled and Labeled Data")
plt.plot(history_merged.history["val_accuracy"], label="Validation Accuracy for Unlabeled and Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title('Training Accuracy - Semi-Supervised Learning')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history_merged.history["loss"], label="Training Loss for Unlabeled and Labeled Data")
plt.plot(history_merged.history["val_loss"], label="Validation Loss for Unlabeled and Labeled Data")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title('Training Loss - Semi-Supervised Learning')
plt.legend()
plt.grid(True)
plt.show()
print(f"\n✅ After Labeled Training - Validation Accuracy: {test_acc * 100:.2f}%")
# Out:
# 🔮 Generating Pseudo-Labels for Unlabeled Data...
# ✅ Generated 2275 pseudo-labels (confidence >= 0.7)
# Found 3075 files belonging to 8 classes.
# ✅ Merged dataset created with 3075 images
#
# 🚀 Phase 2: Training on Merged Data (100 epochs)
# Epoch 1/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.9674 - loss: 0.3514 - val_accuracy: 0.9750 - val_loss: 0.3362 - learning_rate: 0.0010
# Epoch 2/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9792 - loss: 0.3559 - val_accuracy: 0.9600 - val_loss: 0.3588 - learning_rate: 0.0010
# Epoch 3/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9681 - loss: 0.3737 - val_accuracy: 0.9650 - val_loss: 0.3421 - learning_rate: 0.0010
# Epoch 4/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.9685 - loss: 0.3622 - val_accuracy: 0.9775 - val_loss: 0.3205 - learning_rate: 0.0010
# Epoch 5/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9704 - loss: 0.3556 - val_accuracy: 0.9775 - val_loss: 0.3137 - learning_rate: 0.0010
# Epoch 6/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.9796 - loss: 0.3147 - val_accuracy: 0.9750 - val_loss: 0.2984 - learning_rate: 0.0010
# Epoch 7/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9733 - loss: 0.3084 - val_accuracy: 0.9775 - val_loss: 0.2965 - learning_rate: 0.0010
# Epoch 8/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9761 - loss: 0.2978 - val_accuracy: 0.9875 - val_loss: 0.2688 - learning_rate: 0.0010
# Epoch 9/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9716 - loss: 0.3124 - val_accuracy: 0.9775 - val_loss: 0.3121 - learning_rate: 0.0010
# Epoch 10/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9748 - loss: 0.3012 - val_accuracy: 0.9775 - val_loss: 0.2794 - learning_rate: 0.0010
# Epoch 11/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9660 - loss: 0.3620 - val_accuracy: 0.9800 - val_loss: 0.2891 - learning_rate: 0.0010
# Epoch 12/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9791 - loss: 0.3021 - val_accuracy: 0.9800 - val_loss: 0.2943 - learning_rate: 0.0010
# Epoch 13/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9770 - loss: 0.3189 - val_accuracy: 0.9775 - val_loss: 0.2833 - learning_rate: 0.0010
# Epoch 14/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9897 - loss: 0.2671 - val_accuracy: 0.9850 - val_loss: 0.2361 - learning_rate: 5.0000e-04
# Epoch 15/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9915 - loss: 0.2350 - val_accuracy: 0.9875 - val_loss: 0.2131 - learning_rate: 5.0000e-04
# Epoch 16/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9877 - loss: 0.2047 - val_accuracy: 0.9800 - val_loss: 0.2101 - learning_rate: 5.0000e-04
# Epoch 17/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9837 - loss: 0.2203 - val_accuracy: 0.9875 - val_loss: 0.2175 - learning_rate: 5.0000e-04
# Epoch 18/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9886 - loss: 0.2041 - val_accuracy: 0.9850 - val_loss: 0.2170 - learning_rate: 5.0000e-04
# Epoch 19/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9920 - loss: 0.1995 - val_accuracy: 0.9825 - val_loss: 0.1990 - learning_rate: 5.0000e-04
# Epoch 20/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9876 - loss: 0.2133 - val_accuracy: 0.9800 - val_loss: 0.2049 - learning_rate: 5.0000e-04
# Epoch 21/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9922 - loss: 0.1929 - val_accuracy: 0.9800 - val_loss: 0.1941 - learning_rate: 5.0000e-04
# Epoch 22/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.9902 - loss: 0.1868 - val_accuracy: 0.9800 - val_loss: 0.2058 - learning_rate: 5.0000e-04
# Epoch 23/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9891 - loss: 0.1894 - val_accuracy: 0.9875 - val_loss: 0.1850 - learning_rate: 5.0000e-04
# Epoch 24/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9886 - loss: 0.1916 - val_accuracy: 0.9850 - val_loss: 0.1910 - learning_rate: 5.0000e-04
# Epoch 25/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9941 - loss: 0.1757 - val_accuracy: 0.9850 - val_loss: 0.1782 - learning_rate: 5.0000e-04
# Epoch 26/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9875 - loss: 0.1874 - val_accuracy: 0.9775 - val_loss: 0.2023 - learning_rate: 5.0000e-04
# Epoch 27/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9885 - loss: 0.1928 - val_accuracy: 0.9750 - val_loss: 0.1976 - learning_rate: 5.0000e-04
# Epoch 28/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9918 - loss: 0.1781 - val_accuracy: 0.9825 - val_loss: 0.1828 - learning_rate: 5.0000e-04
# Epoch 29/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9883 - loss: 0.1839 - val_accuracy: 0.9875 - val_loss: 0.1786 - learning_rate: 5.0000e-04
# Epoch 30/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9893 - loss: 0.1869 - val_accuracy: 0.9825 - val_loss: 0.1902 - learning_rate: 5.0000e-04
# Epoch 31/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9888 - loss: 0.1759 - val_accuracy: 0.9850 - val_loss: 0.1729 - learning_rate: 2.5000e-04
# Epoch 32/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9933 - loss: 0.1604 - val_accuracy: 0.9875 - val_loss: 0.1733 - learning_rate: 2.5000e-04
# Epoch 33/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9930 - loss: 0.1561 - val_accuracy: 0.9875 - val_loss: 0.1633 - learning_rate: 2.5000e-04
# Epoch 34/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9952 - loss: 0.1460 - val_accuracy: 0.9875 - val_loss: 0.1656 - learning_rate: 2.5000e-04
# Epoch 35/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.9950 - loss: 0.1475 - val_accuracy: 0.9850 - val_loss: 0.1661 - learning_rate: 2.5000e-04
# Epoch 36/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9927 - loss: 0.1498 - val_accuracy: 0.9850 - val_loss: 0.1698 - learning_rate: 2.5000e-04
# Epoch 37/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9954 - loss: 0.1490 - val_accuracy: 0.9850 - val_loss: 0.1656 - learning_rate: 2.5000e-04
# Epoch 38/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9959 - loss: 0.1471 - val_accuracy: 0.9825 - val_loss: 0.1598 - learning_rate: 2.5000e-04
# Epoch 39/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.9930 - loss: 0.1439 - val_accuracy: 0.9800 - val_loss: 0.1703 - learning_rate: 2.5000e-04
# Epoch 40/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9944 - loss: 0.1462 - val_accuracy: 0.9850 - val_loss: 0.1605 - learning_rate: 2.5000e-04
# Epoch 41/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9978 - loss: 0.1391 - val_accuracy: 0.9825 - val_loss: 0.1553 - learning_rate: 2.5000e-04
# Epoch 42/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9915 - loss: 0.1457 - val_accuracy: 0.9800 - val_loss: 0.1606 - learning_rate: 2.5000e-04
# Epoch 43/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9974 - loss: 0.1371 - val_accuracy: 0.9850 - val_loss: 0.1564 - learning_rate: 2.5000e-04
# Epoch 44/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9951 - loss: 0.1369 - val_accuracy: 0.9825 - val_loss: 0.1577 - learning_rate: 2.5000e-04
# Epoch 45/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9964 - loss: 0.1346 - val_accuracy: 0.9800 - val_loss: 0.1646 - learning_rate: 2.5000e-04
# Epoch 46/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9937 - loss: 0.1436 - val_accuracy: 0.9825 - val_loss: 0.1520 - learning_rate: 2.5000e-04
# Epoch 47/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9914 - loss: 0.1440 - val_accuracy: 0.9875 - val_loss: 0.1556 - learning_rate: 2.5000e-04
# Epoch 48/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9966 - loss: 0.1337 - val_accuracy: 0.9775 - val_loss: 0.1759 - learning_rate: 2.5000e-04
# Epoch 49/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9935 - loss: 0.1425 - val_accuracy: 0.9825 - val_loss: 0.1646 - learning_rate: 2.5000e-04
# Epoch 50/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9959 - loss: 0.1391 - val_accuracy: 0.9775 - val_loss: 0.1726 - learning_rate: 2.5000e-04
# Epoch 51/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9945 - loss: 0.1435 - val_accuracy: 0.9850 - val_loss: 0.1671 - learning_rate: 2.5000e-04
# Epoch 52/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9971 - loss: 0.1317 - val_accuracy: 0.9875 - val_loss: 0.1532 - learning_rate: 1.2500e-04
# Epoch 53/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9984 - loss: 0.1252 - val_accuracy: 0.9875 - val_loss: 0.1474 - learning_rate: 1.2500e-04
# Epoch 54/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9981 - loss: 0.1247 - val_accuracy: 0.9850 - val_loss: 0.1461 - learning_rate: 1.2500e-04
# Epoch 55/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9976 - loss: 0.1228 - val_accuracy: 0.9875 - val_loss: 0.1434 - learning_rate: 1.2500e-04
# Epoch 56/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9951 - loss: 0.1251 - val_accuracy: 0.9875 - val_loss: 0.1498 - learning_rate: 1.2500e-04
# Epoch 57/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9957 - loss: 0.1266 - val_accuracy: 0.9850 - val_loss: 0.1437 - learning_rate: 1.2500e-04
# Epoch 58/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 87ms/step - accuracy: 0.9991 - loss: 0.1144 - val_accuracy: 0.9875 - val_loss: 0.1403 - learning_rate: 1.2500e-04
# Epoch 59/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9948 - loss: 0.1229 - val_accuracy: 0.9800 - val_loss: 0.1382 - learning_rate: 1.2500e-04
# Epoch 60/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9988 - loss: 0.1177 - val_accuracy: 0.9825 - val_loss: 0.1459 - learning_rate: 1.2500e-04
# Epoch 61/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9958 - loss: 0.1206 - val_accuracy: 0.9850 - val_loss: 0.1439 - learning_rate: 1.2500e-04
# Epoch 62/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9978 - loss: 0.1209 - val_accuracy: 0.9875 - val_loss: 0.1506 - learning_rate: 1.2500e-04
# Epoch 63/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9985 - loss: 0.1172 - val_accuracy: 0.9850 - val_loss: 0.1515 - learning_rate: 1.2500e-04
# Epoch 64/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.9936 - loss: 0.1283 - val_accuracy: 0.9850 - val_loss: 0.1473 - learning_rate: 1.2500e-04
# Epoch 65/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9982 - loss: 0.1157 - val_accuracy: 0.9850 - val_loss: 0.1436 - learning_rate: 6.2500e-05
# Epoch 66/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 9s 88ms/step - accuracy: 0.9994 - loss: 0.1112 - val_accuracy: 0.9850 - val_loss: 0.1451 - learning_rate: 6.2500e-05
# Epoch 67/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9942 - loss: 0.1199 - val_accuracy: 0.9825 - val_loss: 0.1467 - learning_rate: 6.2500e-05
# Epoch 68/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9982 - loss: 0.1139 - val_accuracy: 0.9875 - val_loss: 0.1412 - learning_rate: 6.2500e-05
# Epoch 69/100
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.9954 - loss: 0.1154 - val_accuracy: 0.9875 - val_loss: 0.1416 - learning_rate: 6.2500e-05
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9730 - loss: 0.1516
#
# 🎯 Final Test Accuracy: 97.00%
# ✅ After Labeled Training - Validation Accuracy: 97.00%

# %%
"""# Step 12: Confusion Matrix"""

y_true = []
y_pred = []

for images, labels in test_dataset:
    predictions = model.predict(images, verbose=0)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(labels.numpy())

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.title("Confusion Matrix - Semi-Supervised Learning", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Recover class names (if .class_names lost)
test_dir = os.path.join(base_dir, 'test')
class_names = sorted(os.listdir(test_dir))

# Collect true labels
y_true = np.concatenate([y for x, y in test_dataset], axis=0)

# Predict
predictions = model.predict(test_dataset)
y_pred = np.argmax(predictions, axis=1)

# Report
print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.98      0.96      0.97        50
# Bacterial Canker       1.00      0.98      0.99        50
#   Cutting Weevil       1.00      1.00      1.00        50
#         Die Back       0.96      1.00      0.98        50
#       Gall Midge       0.98      0.94      0.96        50
#          Healthy       0.91      1.00      0.95        50
#   Powdery Mildew       1.00      0.96      0.98        50
#      Sooty Mould       0.94      0.92      0.93        50
#
#         accuracy                           0.97       400
#        macro avg       0.97      0.97      0.97       400
#     weighted avg       0.97      0.97      0.97       400
